# %% [markdown]
# ### Module Install

# %%
# %pip install --upgrade langchain==0.3.12 langchain_openai==0.2.12  # 0.3.10
# Out:
# Requirement already satisfied: langchain==0.3.12 in /usr/local/lib/python3.11/dist-packages (0.3.12)
# Requirement already satisfied: langchain_openai==0.2.12 in /usr/local/lib/python3.11/dist-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.25 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (0.3.33)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (0.2.11)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain==0.3.12) (9.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.55.3 in /usr/local/lib/python3.11/dist-packages (from langchain_openai==0.2.12) (1.61.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.11/dist-packages (from langchain_openai==0.2.12) (0.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.12) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain==0.3.12) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.55.3->langchain_openai==0.2.12) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.55.3->langchain_openai==0.2.12) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.55.3->langchain_openai==0.2.12) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.55.3->langchain_openai==0.2.12) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.55.3->langchain_openai==0.2.12) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.12) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.12) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.12) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.12) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain==0.3.12) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.12) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain_openai==0.2.12) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain==0.3.12) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.25->langchain==0.3.12) (3.0.0)

# %% [markdown]
# 필요 API 키 입력

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
if "SERPER_API_KEY" not in os.environ:
    os.environ["SERPER_API_KEY"] = getpass.getpass("Enter your SERPER API key: ")
if "rapid_api_key" not in os.environ:
    os.environ["rapid_api_key"] = getpass.getpass("Enter your RAPID API key: ")
if "rapid_api_key_price" not in os.environ:
    os.environ["rapid_api_key_price"] = getpass.getpass("Enter your RAPID STOCK PRICE API key: ")

# %% [markdown]
# # 도구 데코레이터 + Pydantic
#
# 대부분의 경우 입력값의 유효성을 검사하기 위해 Pydantic이 필요합니다. 예를 들어, 시세의 경우 형식은 일반적으로 AAPL, META, GOGL 등과 같이 최대 4자로 구성됩니다. 따라서 사용자 입력이 올바른 형식인지 논리적으로 검증할 수 있습니다. 그렇지 않은 경우 오류를 발생시켜 더 이상 처리하지 않을 수 있습니다. 이러한 접근 방식은 비용과 실행 시간 측면에서 시스템의 효율성을 향상시킵니다.

# %%
import requests
import json
from langchain.agents import create_tool_calling_agent, AgentExecutor
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from pydantic.v1 import BaseModel, Field, validator
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage, ToolMessage
from datetime import datetime

# add pydantic
class SearchInput(BaseModel):
    stock: str = Field(description="Stock ticker to search for")

    @validator('stock')
    def validate_stock(cls, v):
        if not v.isalpha() or len(v) > 4:
            raise ValueError('Stock ticker should only contain up to 4 alphabetic characters')
        return v

# add args_schema=SearchInput inside of the tool decorator
@tool(args_schema=SearchInput)
def get_company_profile(stock:str) -> str:
    # 회사명, 섹터명, 기본 이름, 주식의 직원 수와 같은 세부 프로필 가져오기
    """
    Get the company profile and ratings for a given stock ticker.

    Args:
        stock (str): The stock ticker symbol to search for.

    Returns:
        str: The company profile data in JSON format.
    """
    api_key = os.getenv("rapid_api_key")
    url = "https://seeking-alpha.p.rapidapi.com/symbols/get-ratings"


    querystring = {"symbol":stock.lower()}

    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        result = json.dumps(data)
    else:
        raise ValueError(f"No data for {stock}")

    return result

@tool(args_schema=SearchInput)
def get_competitors(stock:str) -> str:
    """Get peers or competitors of a stock"""

    api_key = os.getenv("rapid_api_key")
    url = "https://seeking-alpha.p.rapidapi.com/symbols/get-peers"

    querystring = {"symbol":stock.lower()}

    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        result = json.dumps(data)
    else:
        raise ValueError(f"No data for {stock}")

    return result

prompt = ChatPromptTemplate.from_messages([
    ("system", "you're a helpful assistant"),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

tools = [get_company_profile, get_competitors]
llm = ChatOpenAI(model_name = "gpt-3.5-turbo", temperature = 0)
agent = create_tool_calling_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose = True)

# %%
get_company_profile('aapl')
# Out:
# '{"data": [{"id": "146,2025-02-07", "type": "rating", "attributes": {"asDate": "2025-02-07", "tickerId": 146, "ratings": {"authorsCount": 32.0, "authorsRating": 2.75, "authorsRatingBuyCount": 4.0, "authorsRatingBuyCount30Day": 4.0, "authorsRatingBuyCount90Day": 5.0, "authorsRatingHoldCount": 13.0, "authorsRatingHoldCount30Day": 13.0, "authorsRatingHoldCount90Day": 22.0, "authorsRatingSellCount": 10.0, "authorsRatingSellCount30Day": 10.0, "authorsRatingSellCount90Day": 17.0, "authorsRatingStrongBuyCount": 2.0, "authorsRatingStrongBuyCount30Day": 2.0, "authorsRatingStrongBuyCount90Day": 2.0, "authorsRatingStrongSellCount": 3.0, "authorsRatingStrongSellCount30Day": 3.0, "authorsRatingStrongSellCount90Day": 5.0, "quantRating": 3.451488792238207, "sellSideRating": 3.93478, "divConsistencyCategoryGrade": 5, "divGrowthCategoryGrade": 1, "divSafetyCategoryGrade": 1, "dividendYieldGrade": 12, "dpsRevisionsGrade": 4, "epsRevisionsGrade": 9, "growthGrade": 11, "momentumGrade": 7, "profitabilityGrade": 1, "valueGrade": 13, "yieldOnCostGrade": 11}}, "meta": {"is_locked": null}}, {"id": "146,2024-11-07", "type": "rating", "attributes": {"asDate": "2024-11-07", "tickerId": 146, "ratings": {"authorsCount": 29.0, "authorsRating": 2.68966, "authorsRatingBuyCount": 4.0, "authorsRatingBuyCount30Day": 4.0, "authorsRatingBuyCount90Day": 10.0, "authorsRatingHoldCount": 12.0, "authorsRatingHoldCount30Day": 12.0, "authorsRatingHoldCount90Day": 30.0, "authorsRatingSellCount": 9.0, "authorsRatingSellCount30Day": 9.0, "authorsRatingSellCount90Day": 16.0, "authorsRatingStrongBuyCount": 1.0, "authorsRatingStrongBuyCount30Day": 1.0, "authorsRatingStrongBuyCount90Day": 3.0, "authorsRatingStrongSellCount": 3.0, "authorsRatingStrongSellCount30Day": 3.0, "authorsRatingStrongSellCount90Day": 4.0, "quantRating": 3.425192888292519, "sellSideRating": 4.10638, "divConsistencyCategoryGrade": 5, "divGrowthCategoryGrade": 1, "divSafetyCategoryGrade": 2, "dividendYieldGrade": 11, "dpsRevisionsGrade": 7, "epsRevisionsGrade": 9, "growthGrade": 11, "momentumGrade": 6, "profitabilityGrade": 1, "valueGrade": 11, "yieldOnCostGrade": 11}}, "meta": {"is_locked": null}}, {"id": "146,2024-08-07", "type": "rating", "attributes": {"asDate": "2024-08-07", "tickerId": 146, "ratings": {"authorsCount": 21.0, "authorsRating": 2.85714, "authorsRatingBuyCount": 6.0, "authorsRatingBuyCount30Day": 6.0, "authorsRatingBuyCount90Day": 14.0, "authorsRatingHoldCount": 8.0, "authorsRatingHoldCount30Day": 8.0, "authorsRatingHoldCount90Day": 19.0, "authorsRatingSellCount": 5.0, "authorsRatingSellCount30Day": 5.0, "authorsRatingSellCount90Day": 11.0, "authorsRatingStrongBuyCount": 0.0, "authorsRatingStrongBuyCount30Day": 0.0, "authorsRatingStrongBuyCount90Day": 3.0, "authorsRatingStrongSellCount": 2.0, "authorsRatingStrongSellCount30Day": 2.0, "authorsRatingStrongSellCount90Day": 3.0, "quantRating": 3.490067399787159, "sellSideRating": 4.17778, "divSafetyCategoryGrade": 2, "divGrowthCategoryGrade": 2, "divConsistencyCategoryGrade": 5, "dividendYieldGrade": 11, "growthGrade": 11, "profitabilityGrade": 1, "momentumGrade": 5, "valueGrade": 13, "epsRevisionsGrade": 4, "dpsRevisionsGrade": 10, "yieldOnCostGrade": 11}}, "meta": {"is_locked": null}}], "meta": {"hasTodayRatings": true}}'

# %% [markdown]
# 다만 정확히 입력하지 않을 경우 아래와 같이 에러 발생

# %%
query = "I'm an investor, what is AAPLLLLLLL"
print("Question:", query)
result = agent_executor.invoke({"input": query})
print("Answer:",result['output'])
# Out:
# Question: I'm an investor, what is AAPLLLLLLL
#
#
# > Entering new AgentExecutor chain...
#
# Invoking: `get_company_profile` with `{'stock': 'AAPLLLLLLL'}`
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-23-1752e855c04a> in <cell line: 0>()
#       1 query = "I'm an investor, what is AAPLLLLLLL"
#       2 print("Question:", query)
# ----> 3 result = agent_executor.invoke({"input": query})
#       4 print("Answer:",result['output'])
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/agents/agent.py in _call(self, inputs, run_manager)
#    1622         # We now enter the agent loop (until it returns something).
#    1623         while self._should_continue(iterations, time_elapsed):
# -> 1624             next_step_output = self._take_next_step(
#    1625                 name_to_tool_map,
#    1626                 color_mapping,
#
# /usr/local/lib/python3.11/dist-packages/langchain/agents/agent.py in _take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1328     ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1329         return self._consume_next_step(
# -> 1330             [
#    1331                 a
#    1332                 for a in self._iter_next_step(
#
# /usr/local/lib/python3.11/dist-packages/langchain/agents/agent.py in <listcomp>(.0)
#    1328     ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1329         return self._consume_next_step(
# -> 1330             [
#    1331                 a
#    1332                 for a in self._iter_next_step(
#
# /usr/local/lib/python3.11/dist-packages/langchain/agents/agent.py in _iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1413             yield agent_action
#    1414         for agent_action in actions:
# -> 1415             yield self._perform_agent_action(
#    1416                 name_to_tool_map, color_mapping, agent_action, run_manager
#    1417             )
#
# /usr/local/lib/python3.11/dist-packages/langchain/agents/agent.py in _perform_agent_action(self, name_to_tool_map, color_mapping, agent_action, run_manager)
#    1435                 tool_run_kwargs["llm_prefix"] = ""
#    1436             # We then call the tool on the tool input to get an observation
# -> 1437             observation = tool.run(
#    1438                 agent_action.tool_input,
#    1439                 verbose=self.verbose,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/tools/base.py in run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     723         if error_to_raise:
#     724             run_manager.on_tool_error(error_to_raise)
# --> 725             raise error_to_raise
#     726         output = _format_output(content, artifact, tool_call_id, self.name, status)
#     727         run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/tools/base.py in run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     687             context = copy_context()
#     688             context.run(_set_config_context, child_config)
# --> 689             tool_args, tool_kwargs = self._to_args_and_kwargs(tool_input, tool_call_id)
#     690             if signature(self._run).parameters.get("run_manager"):
#     691                 tool_kwargs = tool_kwargs | {"run_manager": run_manager}
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/tools/base.py in _to_args_and_kwargs(self, tool_input, tool_call_id)
#     609             # StructuredTool with no args
#     610             return (), {}
# --> 611         tool_input = self._parse_input(tool_input, tool_call_id)
#     612         # For backwards compatibility, if run_input is a string,
#     613         # pass as a positional argument.
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/tools/base.py in _parse_input(self, tool_input, tool_call_id)
#     548                                 raise ValueError(msg)
#     549                             tool_input[k] = tool_call_id
# --> 550                     result = input_args.parse_obj(tool_input)
#     551                     result_dict = result.dict()
#     552                 else:
#
# /usr/local/lib/python3.11/dist-packages/pydantic/v1/main.py in parse_obj(cls, obj)
#     524                 exc = TypeError(f'{cls.__name__} expected dict not {obj.__class__.__name__}')
#     525                 raise ValidationError([ErrorWrapper(exc, loc=ROOT_KEY)], cls) from e
# --> 526         return cls(**obj)
#     527
#     528     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/pydantic/v1/main.py in __init__(__pydantic_self__, **data)
#     339         values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340         if validation_error:
# --> 341             raise validation_error
#     342         try:
#     343             object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for SearchInput
# stock
#   Stock ticker should only contain up to 4 alphabetic characters (type=value_error)

# %% [markdown]
# # Structured Tools
# https://blog.langchain.dev/structured-tools/

# %% [markdown]
# ValueError가 발생하면 시스템이 중단되어 중간에 오류가 발생하면서 프로세스가 중단됩니다. 예를 들어 챗봇의 경우 아무런 설명도 제공하지 않고 갑자기 멈출 수 있습니다. 따라서 우리는 **에러 처리**가 필요합니다. Langchain은 이미 ToolException을 제공하고 있지만, 구조화된 도구나 기본 클래스를 통해서만 접근할 수 있습니다. 도구 데코레이터를 사용하여 ToolException을 구현할 수 없으므로 @tool이 항상 충분하지 않은 이유를 설명합니다. 유연성을 높이려면 StructuredTools를 사용해야 합니다.
#
# 1. ValueError를 ToolException으로 변경합니다.
# 2. handle_tool_error = True로 변경합니다.

# %%
from pydantic.v1 import BaseModel, Field, validator
from datetime import datetime
from langchain_core.tools import StructuredTool
from langchain_core.tools import ToolException

# change ValueError to ToolException
class SearchInput(BaseModel):
    stock: str = Field(description="Stock ticker to search for")

    @validator('stock')
    def validate_stock(cls, v):
        if not v.isalpha() or len(v) > 4:
            raise ToolException('Stock ticker should only contain up to 4 alphabetic characters')
        return v

def get_company_profile(stock:str) -> str:
    """Get detail profile such as company name, sector name, primary name, number of employees of a stock"""

    api_key = os.getenv("rapid_api_key")
    url = "https://seeking-alpha.p.rapidapi.com/symbols/get-profile"

    querystring = {"symbols":stock.lower()}

    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        result = json.dumps(data)
    else:
        raise ToolException(f"No data for {stock}")

    return result

def get_competitors(stock:str) -> str:
    """Get peers or competitors of a stock"""

    api_key = os.getenv("rapid_api_key")
    url = "https://seeking-alpha.p.rapidapi.com/symbols/get-peers"

    querystring = {"symbol":stock.lower()}

    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        result = json.dumps(data)
    else:
        raise ToolException(f"No data for {stock}")

    return result


get_company_profile_tool = StructuredTool.from_function(
    func=get_company_profile,
    args_schema= SearchInput,
    handle_tool_error=True, # add this
)

get_competitors_tool = StructuredTool.from_function(
    func=get_competitors,
    args_schema= SearchInput,
    handle_tool_error=True, # add this
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "you're a helpful assistant"),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}"),
])

tools = [get_company_profile_tool, get_competitors_tool]

agent = create_tool_calling_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose = True)

# %%
query = "I'm an investor, what is AAPL"
print("Question:", query)
result = agent_executor.invoke({"input": query})
print("Answer:",result['output'])
# Out:
# Question: I'm an investor, what is AAPL
#
#
# > Entering new AgentExecutor chain...
#
# Invoking: `get_company_profile` with `{'stock': 'AAPL'}`
#
#
# {"data": [{"id": "AAPL", "tickerId": 146, "attributes": {"longDesc": "Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.", "sectorname": "Information Technology", "sectorgics": 45, "primaryname": "Technology Hardware, Storage and Peripherals", "primarygics": 45202030, "numberOfEmployees": 164000.0, "yearfounded": 1976, "streetaddress": "One Apple Park Way", "streetaddress2": null, "streetaddress3": null, "streetaddress4": null, "city": "Cupertino", "state": "CA", "zipcode": "95014", "country": "United States", "officephonevalue": "(408) 996-1010", "webpage": "www.apple.com", "companyName": "Apple Inc.", "marketCap": 3492181310310.0, "totalEnterprise": 3447612310310.0, "totAnalystsRecommendations": 46.0, "fy1UpRevisions": 11.0, "fy1DownRevisions": 16.0, "divYield": 0.43, "eps": 6.310391, "lastDaily": {"rtTime": "2025-02-06T21:00:00.000+00:00", "rtSource": "RealTimeQuote", "last": 233.22, "open": 231.285, "close": 233.22, "low": 230.425, "high": 233.8, "volume": 29925349, "volumeAt": "2025-02-06T21:00:00.000+00:00", "at": "2025-02-07T01:30:02.927-05:00"}, "estimateEps": 7.34841, "debtEq": 144.9998, "totDebtCap": 59.1836, "ltDebtEquity": 125.7617, "ltDebtCap": 51.3313, "totLiabTotAssets": 80.5983, "impliedMarketCap": null, "shortIntPctFloat": null, "divTimeFrame": "forward", "divRate": 1.0, "peRatioFwd": 31.7374779033832, "lastClosePriceEarningsRatio": 37.0206579634864, "estimateFfo": null, "ffoPerShareDiluted": null, "dilutedEpsExclExtraItems": null, "high52": null, "low52": null}}]}AAPL is the stock ticker for Apple Inc. Apple designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers a range of products including iPhone, Mac, iPad, wearables, and accessories. Apple also provides services such as AppleCare support, cloud services, and operates platforms like the App Store.
#
# Here are some key details about Apple Inc.:
# - Sector: Information Technology
# - Industry: Technology Hardware, Storage and Peripherals
# - Number of Employees: 164,000
# - Year Founded: 1976
# - Headquarters: Cupertino, California
# - Website: [www.apple.com](www.apple.com)
# - Market Cap: $3,492,181,310,310
# - Current Stock Price: $233.22
#
# If you would like more information or have any specific questions about Apple Inc., feel free to ask!
#
# > Finished chain.
# Answer: AAPL is the stock ticker for Apple Inc. Apple designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers a range of products including iPhone, Mac, iPad, wearables, and accessories. Apple also provides services such as AppleCare support, cloud services, and operates platforms like the App Store.
#
# Here are some key details about Apple Inc.:
# - Sector: Information Technology
# - Industry: Technology Hardware, Storage and Peripherals
# - Number of Employees: 164,000
# - Year Founded: 1976
# - Headquarters: Cupertino, California
# - Website: [www.apple.com](www.apple.com)
# - Market Cap: $3,492,181,310,310
# - Current Stock Price: $233.22
#
# If you would like more information or have any specific questions about Apple Inc., feel free to ask!

# %% [markdown]
# * 실시간의 데이터를 가져오기 때문에 장이 운영하지 않는 시간/기간에는 값이 없을 수 있습니다.

# %%
import requests

url = "https://seeking-alpha.p.rapidapi.com/v2/auto-complete"

querystring = {"query":"apple","type":"people,symbols,pages","size":"5"}

headers = {
	"x-rapidapi-key": "58c32f5dd8mshc7da181b67a6bcep110a60jsnbea62f8b288b",
	"x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'people': [{'id': 51516124, 'type': 'user', 'score': 897.93225, 'url': '/user/51516124', 'name': 'Tim <b>Apple</b>', 'slug': 'tim-apple'}, {'id': 30855475, 'type': 'user', 'score': 566.8791, 'url': '/user/30855475', 'name': '<b>Apple</b> Eye', 'slug': 'apple-eye'}, {'id': 51054234, 'type': 'user', 'score': 515.19904, 'url': '/user/51054234', 'name': 'pine-<b>apple</b>', 'slug': 'pine-apple'}, {'id': 107710, 'type': 'author', 'score': 96.882576, 'url': '/author/appleseed-fund', 'name': '<b>Appleseed</b> Fund', 'slug': 'appleseed-fund'}, {'id': 69175, 'type': 'author', 'score': 96.280334, 'url': '/author/business-quant', 'name': 'Business Quant', 'slug': 'business-quant'}], 'symbols': [{'id': 146, 'type': 'symbol', 'score': 31737.53, 'url': '/symbol/AAPL', 'name': 'AAPL', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl'}, {'id': 513836, 'type': 'symbol', 'score': 20161.338, 'url': '/symbol/APLE', 'name': 'APLE', 'content': '<b>Apple</b> Hospitality REIT, Inc.', 'slug': 'aple'}, {'id': 764528, 'type': 'symbol', 'score': 14685.48, 'url': '/symbol/AAPL:CA', 'name': 'AAPL:CA', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl:ca'}, {'id': 20465, 'type': 'symbol', 'score': 13658.648, 'url': '/symbol/APRU', 'name': 'APRU', 'content': '<b>Apple</b> Rush Company, Inc.', 'slug': 'apru'}, {'id': 24895, 'type': 'symbol', 'score': 12256.517, 'url': '/symbol/GAPJ', 'name': 'GAPJ', 'content': 'Golden <b>Apple</b> Oil & Gas Inc.', 'slug': 'gapj'}], 'pages': [{'id': 332, 'type': 'page', 'score': 2909.4575, 'url': 'comparison/9e-FAANG-Stocks', 'name': 'FAANG Stocks Comparison'}]}

# %%
import requests

def get_stock_symbol(query: str) -> str:
    url = "https://seeking-alpha.p.rapidapi.com/v2/auto-complete"
    querystring = {"query":query,"type":"people,symbols,pages","size":"5"}
    # 기업명 기반으로 주식 정보를 가져오기 위한 함수
    headers = {
        "x-rapidapi-key": os.getenv("rapid_api_key_price"),
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        print(data)
        # 첫 번째 결과의 심볼 반환
        if "symbols" in data and len(data["symbols"]) > 0:
            symbol = data['symbols'][0]['name']
            s_id = data['symbols'][0]['id']
            return symbol, s_id
        else:
            return None
    else:
        print(response)
        raise Exception(f"Failed to fetch stock symbol: {response.status_code}")

symbol = get_stock_symbol("Apple")
print(symbol)
# Out:
# {'people': [{'id': 51516124, 'type': 'user', 'score': 884.8182, 'url': '/user/51516124', 'name': 'Tim <b>Apple</b>', 'slug': 'tim-apple'}, {'id': 30855475, 'type': 'user', 'score': 558.6, 'url': '/user/30855475', 'name': '<b>Apple</b> Eye', 'slug': 'apple-eye'}, {'id': 51054234, 'type': 'user', 'score': 507.74622, 'url': '/user/51054234', 'name': 'pine-<b>apple</b>', 'slug': 'pine-apple'}, {'id': 107710, 'type': 'author', 'score': 96.84719, 'url': '/author/appleseed-fund', 'name': '<b>Appleseed</b> Fund', 'slug': 'appleseed-fund'}, {'id': 69175, 'type': 'author', 'score': 96.168655, 'url': '/author/business-quant', 'name': 'Business Quant', 'slug': 'business-quant'}], 'symbols': [{'id': 146, 'type': 'symbol', 'score': 31737.53, 'url': '/symbol/AAPL', 'name': 'AAPL', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl'}, {'id': 513836, 'type': 'symbol', 'score': 20161.338, 'url': '/symbol/APLE', 'name': 'APLE', 'content': '<b>Apple</b> Hospitality REIT, Inc.', 'slug': 'aple'}, {'id': 764528, 'type': 'symbol', 'score': 14685.48, 'url': '/symbol/AAPL:CA', 'name': 'AAPL:CA', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl:ca'}, {'id': 20465, 'type': 'symbol', 'score': 13658.648, 'url': '/symbol/APRU', 'name': 'APRU', 'content': '<b>Apple</b> Rush Company, Inc.', 'slug': 'apru'}, {'id': 24895, 'type': 'symbol', 'score': 12256.517, 'url': '/symbol/GAPJ', 'name': 'GAPJ', 'content': 'Golden <b>Apple</b> Oil & Gas Inc.', 'slug': 'gapj'}], 'pages': [{'id': 332, 'type': 'page', 'score': 2909.4575, 'url': 'comparison/9e-FAANG-Stocks', 'name': 'FAANG Stocks Comparison'}]}
# ('AAPL', 146)

# %%
def get_realtime_stock_price(symbol: str) -> dict:
    url = "https://seeking-alpha.p.rapidapi.com/market/get-realtime-quotes"
    querystring = {"sa_ids": symbol}
    '''회사의 최신 주가 확인하기'''
    headers = {
        "x-rapidapi-key": os.getenv("rapid_api_key_price"),
        "x-rapidapi-host": "seeking-alpha.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    if response.status_code == 200:
        data = response.json()
        return data.get("real_time_quotes", {})
    else:
        raise Exception(f"실시간 데이터 가져오기에 실패했습니다: {response.status_code}")

price_data = get_realtime_stock_price('146')
print(price_data)
# Out:
# [{'ticker_id': 146, 'sa_id': 146, 'sa_slug': 'aapl', 'symbol': 'AAPL', 'high': 234, 'low': 227.26, 'open': 232.6, 'close': 227.63, 'prev_close': 233.22, 'last': 227.63, 'volume': 39707224, 'last_time': '2025-02-07T16:00:00.000-05:00', 'ext_time': '2025-02-07T19:59:59.000-05:00', 'ext_price': 227.2889, 'ext_market': 'post', 'info': 'Market Close', 'src': 'UpdateLastQuote', 'updated_at': '2025-02-07T21:01:50.895-05:00'}]

# %%
def fetch_stock_price(query: str) -> str:
    try:
        # 1: 주식 심볼 추출
        symbol,s_id = get_stock_symbol(query)
        print(symbol,s_id)
        if not symbol:
            return f"'{query}'에 대한 심볼을 찾을 수 없습니다."

        # 2: 실시간 주식 가격 추출
        stock_data = get_realtime_stock_price(s_id)
        if not stock_data:
            return f"실시간 데이터를 사용할 수 없습니다: '{symbol}'."

        # 관련 값 추출
        price = stock_data[0].get("last", "N/A")
        return f"{symbol}의 현재 가격은 ${price}입니다."
    except Exception as e:
        return str(e)

# %%
print(fetch_stock_price("Apple"))  # "The current price of AAPL is $123.45."
# Out:
# {'people': [{'id': 51516124, 'type': 'user', 'score': 884.8182, 'url': '/user/51516124', 'name': 'Tim <b>Apple</b>', 'slug': 'tim-apple'}, {'id': 30855475, 'type': 'user', 'score': 558.6, 'url': '/user/30855475', 'name': '<b>Apple</b> Eye', 'slug': 'apple-eye'}, {'id': 51054234, 'type': 'user', 'score': 507.74622, 'url': '/user/51054234', 'name': 'pine-<b>apple</b>', 'slug': 'pine-apple'}, {'id': 107710, 'type': 'author', 'score': 96.84719, 'url': '/author/appleseed-fund', 'name': '<b>Appleseed</b> Fund', 'slug': 'appleseed-fund'}, {'id': 69175, 'type': 'author', 'score': 96.168655, 'url': '/author/business-quant', 'name': 'Business Quant', 'slug': 'business-quant'}], 'symbols': [{'id': 146, 'type': 'symbol', 'score': 31737.53, 'url': '/symbol/AAPL', 'name': 'AAPL', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl'}, {'id': 513836, 'type': 'symbol', 'score': 20161.338, 'url': '/symbol/APLE', 'name': 'APLE', 'content': '<b>Apple</b> Hospitality REIT, Inc.', 'slug': 'aple'}, {'id': 764528, 'type': 'symbol', 'score': 14685.48, 'url': '/symbol/AAPL:CA', 'name': 'AAPL:CA', 'content': '<b>Apple</b> Inc.', 'slug': 'aapl:ca'}, {'id': 20465, 'type': 'symbol', 'score': 13658.648, 'url': '/symbol/APRU', 'name': 'APRU', 'content': '<b>Apple</b> Rush Company, Inc.', 'slug': 'apru'}, {'id': 24895, 'type': 'symbol', 'score': 12256.517, 'url': '/symbol/GAPJ', 'name': 'GAPJ', 'content': 'Golden <b>Apple</b> Oil & Gas Inc.', 'slug': 'gapj'}], 'pages': [{'id': 332, 'type': 'page', 'score': 2909.4575, 'url': 'comparison/9e-FAANG-Stocks', 'name': 'FAANG Stocks Comparison'}]}
# AAPL 146
# AAPL의 현재 가격은 $227.63입니다.

# %%
def monitor_stock_price(stock: str, threshold: float):
    price_info = fetch_stock_price(stock)
    current_price = float(price_info.split('$')[-1].split('.')[0])

    if current_price >= threshold:
        print(f"{stock} 주가가 ${threshold} 이상입니다. 현재 주가: ${current_price}. 매도 고려하세요.")
    else:
        print(f"{stock} 주가가 ${threshold} 이하입니다. 현재 주가: ${current_price}. 매수 고려하세요.")

# Example Usage
monitor_stock_price("AAPL", 200.00)
# Out:
# {'people': [{'id': 43904656, 'type': 'user', 'score': 2166.3674, 'url': '/user/43904656', 'name': 'All*<b>AAPL</b>', 'slug': 'all-aapl'}, {'id': 104905, 'type': 'author', 'score': 67.0355, 'url': '/author/niki-schranz', 'name': 'Niki Schranz', 'slug': 'niki-schranz'}, {'id': 51312, 'type': 'author', 'score': 23.78358, 'url': '/author/jim-wallingford', 'name': 'Jim Wallingford', 'slug': 'jim-wallingford'}, {'id': 98186, 'type': 'author', 'score': 20.303461, 'url': '/author/dividend-nut', 'name': 'Dividend Nut', 'slug': 'dividend-nut'}, {'id': 23971, 'type': 'author', 'score': 20.108665, 'url': '/author/michael-bryant', 'name': 'Michael Bryant', 'slug': 'michael-bryant'}], 'symbols': [{'id': 146, 'type': 'symbol', 'score': 817703.6, 'url': '/symbol/AAPL', 'name': '<b>AAPL</b>', 'content': 'Apple Inc.', 'slug': 'aapl'}, {'id': 764528, 'type': 'symbol', 'score': 18701.996, 'url': '/symbol/AAPL:CA', 'name': '<b>AAPL:CA</b>', 'content': 'Apple Inc.', 'slug': 'aapl:ca'}, {'id': 719409, 'type': 'symbol', 'score': 16683.984, 'url': '/symbol/APLY', 'name': 'APLY', 'content': 'YieldMax <b>AAPL</b> Option Income Strategy ETF', 'slug': 'aply'}, {'id': 631483, 'type': 'symbol', 'score': 13882.768, 'url': '/symbol/AAPU', 'name': 'AAPU', 'content': 'Direxion Daily <b>AAPL</b> Bull 2X Shares ETF', 'slug': 'aapu'}, {'id': 631242, 'type': 'symbol', 'score': 13027.889, 'url': '/symbol/AAPB', 'name': 'AAPB', 'content': 'GraniteShares 2x Long <b>AAPL</b> Daily ETF', 'slug': 'aapb'}], 'pages': [{'id': 223, 'type': 'page', 'score': 4304.2393, 'url': 'symbol/AAPL/income-statement', 'name': 'AAPL Income Statement'}, {'id': 259, 'type': 'page', 'score': 4304.2393, 'url': 'symbol/AAPL/ratings/quant-ratings', 'name': 'AAPL Quant Rating'}, {'id': 224, 'type': 'page', 'score': 4005.4075, 'url': 'symbol/AAPL/earnings', 'name': 'AAPL Earnings'}, {'id': 341, 'type': 'page', 'score': 3708.7405, 'url': 'symbol/AAPL/dividends/history', 'name': 'AAPL Dividend History'}, {'id': 222, 'type': 'page', 'score': 2009.6002, 'url': 'symbol/AAPL/balance-sheet', 'name': 'AAPL Balance Sheet'}]}
# <b>AAPL</b> 146
# AAPL 주가가 $200.0 이상입니다. 현재 주가: $227.0. 매도 고려하세요.

# %%
query = "AAPL 관련 뉴스를 분석하고, 주가 변동성을 알려줘."
result = agent_executor.invoke({"input": query})
print("Answer:", result['output'])
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `get_company_profile` with `{'stock': 'AAPL'}`
#
#
# {"data": [{"id": "AAPL", "tickerId": 146, "attributes": {"longDesc": "Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.", "sectorname": "Information Technology", "sectorgics": 45, "primaryname": "Technology Hardware, Storage and Peripherals", "primarygics": 45202030, "numberOfEmployees": 164000.0, "yearfounded": 1976, "streetaddress": "One Apple Park Way", "streetaddress2": null, "streetaddress3": null, "streetaddress4": null, "city": "Cupertino", "state": "CA", "zipcode": "95014", "country": "United States", "officephonevalue": "(408) 996-1010", "webpage": "www.apple.com", "companyName": "Apple Inc.", "marketCap": 3492181310310.0, "totalEnterprise": 3447612310310.0, "totAnalystsRecommendations": 46.0, "fy1UpRevisions": 11.0, "fy1DownRevisions": 16.0, "divYield": 0.43, "eps": 6.310391, "lastDaily": {"rtTime": "2025-02-06T21:00:00.000+00:00", "rtSource": "RealTimeQuote", "last": 233.22, "open": 231.285, "close": 233.22, "low": 230.425, "high": 233.8, "volume": 29925349, "volumeAt": "2025-02-06T21:00:00.000+00:00", "at": "2025-02-07T01:30:02.927-05:00"}, "estimateEps": 7.34841, "debtEq": 144.9998, "totDebtCap": 59.1836, "ltDebtEquity": 125.7617, "ltDebtCap": 51.3313, "totLiabTotAssets": 80.5983, "impliedMarketCap": null, "shortIntPctFloat": null, "divTimeFrame": "forward", "divRate": 1.0, "peRatioFwd": 31.7374779033832, "lastClosePriceEarningsRatio": 37.0206579634864, "estimateFfo": null, "ffoPerShareDiluted": null, "dilutedEpsExclExtraItems": null, "high52": null, "low52": null}}]}
# Invoking: `get_competitors` with `{'stock': 'AAPL'}`
#
#
# {"data": [{"id": "584719", "type": "ticker", "attributes": {"slug": "xiacy", "name": "XIACY", "companyName": "Xiaomi Corporation", "equityType": "stocks", "indexGroup": null, "currency": "USD", "tradingViewSlug": "OTC:XIACY", "exchange": "Pink Current Info", "exchangeDescription": null, "company": "Xiaomi Corporation", "isBdc": false, "visible": true, "searchable": true, "private": false, "pending": false, "isDefunct": false, "followersCount": 3911, "fundTypeId": 8, "articleRtaCount": 1, "newsRtaCount": 5, "divYieldType": null, "primaryEpsConsensusMeanType": "normalized", "mergedOn": null, "isReit": false}, "relationships": {"sector": {"data": {"id": "45", "type": "sector"}}, "subIndustry": {"data": {"id": "45202030", "type": "subIndustry"}}}, "meta": {"companyLogoUrlLight": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_light/XIACY.svg", "companyLogoUrlDark": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_dark/XIACY.svg"}}, {"id": "569700", "type": "ticker", "attributes": {"slug": "dell", "name": "DELL", "companyName": "Dell Technologies Inc.", "equityType": "stocks", "indexGroup": null, "currency": "USD", "tradingViewSlug": "NYSE:DELL", "exchange": "NYSE", "exchangeDescription": null, "company": "Dell Technologies Inc.", "isBdc": false, "visible": true, "searchable": true, "private": false, "pending": false, "isDefunct": false, "followersCount": 101950, "fundTypeId": 0, "articleRtaCount": 5, "newsRtaCount": 6, "divYieldType": "forward", "primaryEpsConsensusMeanType": "normalized", "mergedOn": null, "isReit": false}, "relationships": {"sector": {"data": {"id": "45", "type": "sector"}}, "subIndustry": {"data": {"id": "45202030", "type": "subIndustry"}}}, "meta": {"companyLogoUrlLight": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_light/DELL.svg", "companyLogoUrlDark": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_dark/DELL.svg"}}, {"id": "933", "type": "ticker", "attributes": {"slug": "hpq", "name": "HPQ", "companyName": "HP Inc.", "equityType": "stocks", "indexGroup": null, "currency": "USD", "tradingViewSlug": "NYSE:HPQ", "exchange": "NYSE", "exchangeDescription": null, "company": "HP Inc.", "isBdc": false, "visible": true, "searchable": true, "private": false, "pending": false, "isDefunct": false, "followersCount": 130561, "fundTypeId": 0, "articleRtaCount": 1, "newsRtaCount": 3, "divYieldType": "forward", "primaryEpsConsensusMeanType": "normalized", "mergedOn": null, "isReit": false}, "relationships": {"sector": {"data": {"id": "45", "type": "sector"}}, "subIndustry": {"data": {"id": "45202030", "type": "subIndustry"}}}, "meta": {"companyLogoUrlLight": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_light/HPQ.svg", "companyLogoUrlDark": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_dark/HPQ.svg"}}, {"id": "545406", "type": "ticker", "attributes": {"slug": "hpe", "name": "HPE", "companyName": "Hewlett Packard Enterprise Company", "equityType": "stocks", "indexGroup": null, "currency": "USD", "tradingViewSlug": "NYSE:HPE", "exchange": "NYSE", "exchangeDescription": null, "company": "Hewlett Packard Enterprise Company", "isBdc": false, "visible": true, "searchable": true, "private": false, "pending": false, "isDefunct": false, "followersCount": 122003, "fundTypeId": 0, "articleRtaCount": 1, "newsRtaCount": 16, "divYieldType": "forward", "primaryEpsConsensusMeanType": "normalized", "mergedOn": null, "isReit": false}, "relationships": {"sector": {"data": {"id": "45", "type": "sector"}}, "subIndustry": {"data": {"id": "45202030", "type": "subIndustry"}}}, "meta": {"companyLogoUrlLight": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_light/HPE.svg", "companyLogoUrlDark": "https://static.seekingalpha.com/cdn/s3/company_logos/mark_vector_dark/HPE.svg"}}, {"id": "24828", "type": "ticker", "attributes": {"slug": "fujiy", "name": "FUJIY", "companyName": "FUJIFILM Holdings Corporation", "equityType": " ...
#
# AAPL의 경쟁사로는 Xiaomi Corporation, Dell Technologies Inc., HP Inc., Hewlett Packard Enterprise Company, FUJIFILM Holdings Corporation 등이 있습니다.
#
# 주가 변동성에 대한 정보는 현재 제공되지 않았습니다. 추가 정보가 필요하시면 알려주세요.
#
# > Finished chain.
# Answer: AAPL(애플)은 정보기술 섹터의 기업으로, 주요 제품으로는 iPhone, Mac, iPad, AirPods, Apple Watch 등을 생산하고 있습니다. 본사는 쿠퍼티노에 위치하며, 164,000명의 직원을 고용하고 있습니다. 주가는 최근 233.22달러로 종가를 기록했습니다.
#
# AAPL의 경쟁사로는 Xiaomi Corporation, Dell Technologies Inc., HP Inc., Hewlett Packard Enterprise Company, FUJIFILM Holdings Corporation 등이 있습니다.
#
# 주가 변동성에 대한 정보는 현재 제공되지 않았습니다. 추가 정보가 필요하시면 알려주세요.

# %% [markdown]
# ## 투자전략 수립

# %%
if "NEWS_API_KEY" not in os.environ:
    os.environ["NEWS_API_KEY"] = getpass.getpass("Enter your NEWS_API_KEY: ")

# %%
import json
from typing import Dict, Any
from datetime import timedelta

def get_news_sentiment(topic: str) -> Dict[str, Any]:
    """특정 주제에 대한 뉴스 기사의 감성을 분석합니다."""

    # NewsAPI 설정
    NEWS_API_KEY = os.getenv('NEWS_API_KEY')
    news_api_url = "https://newsapi.org/v2/everything"

    # 날짜 범위 설정
    end_date = datetime.now()
    start_date = end_date - timedelta(days=7)

    querystring = {
        "q": topic,
        "from": start_date.strftime("%Y-%m-%d"),
        "to": end_date.strftime("%Y-%m-%d"),
        "language": "ko",
        "sortBy": "relevancy",
        "apiKey": NEWS_API_KEY
    }

    try:
        response = requests.get(news_api_url, params=querystring)
        articles = response.json().get('articles', [])

        if not articles:
            return {
                "topic": topic,
                "average_sentiment": 0,
                "analyzed_articles": 0,
                "sentiment_summary": "데이터 없음"
            }

        # 감성 분석을 위한 OpenAI 설정
        llm = ChatOpenAI(
            model="gpt-3.5-turbo",
            temperature=0,
        )

        # 각 기사에 대한 감성 분석
        sentiment_scores = []
        print(articles[:10])
        for article in articles[:10]:  # 최근 10개 기사만 분석
            if article['description'] != '[Removed]':
                prompt = ChatPromptTemplate.from_messages([
                    ("system", "뉴스 기사의 감성을 분석하여 아래와 같은 JSON 형태로 응답하세요. "
                "결과는 'score'는 -1(매우 부정적)에서 1(매우 긍정적) 사이의 값이고, "
                "'explanation'은 해당 감성 점수에 대한 설명을 포함합니다."),
                    ("user", f"제목: {article['title']}\n내용: {article['description']}")
                ])

                chain = prompt | llm
                result = chain.invoke({})
                try:
                    response_json = json.loads(result.content)
                    score = float(response_json['score'])
                    if score != 0:
                        print(response_json)
                    sentiment_scores.append(score)
                except (json.JSONDecodeError, KeyError, ValueError) as e:
                    print(f"파싱 에러 결과: {e}")
                    continue

        # 종합 감성 점수 계산
        if sentiment_scores:
            avg_sentiment = sum(sentiment_scores) / len(sentiment_scores)
            return {
                "topic": topic,
                "average_sentiment": round(avg_sentiment, 2),
                "analyzed_articles": len(sentiment_scores),
                "sentiment_summary": "긍정적" if avg_sentiment > 0.3 else "부정적" if avg_sentiment < -0.3 else "중립적"
            }
        else:
            return {
                "topic": topic,
                "average_sentiment": 0,
                "analyzed_articles": 0,
                "sentiment_summary": "분석 불가"
            }

    except Exception as e:
        print('❌',e)
        return {
            "topic": topic,
            "average_sentiment": 0,
            "analyzed_articles": 0,
            "sentiment_summary": f"에러 발생: {str(e)}"
        }

get_news_sentiment('삼성전자')
# Out:
# [{'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '오효진', 'title': '십일리터 ‘라이펫’, 삼성전자 C-랩 아웃사이드 선정', 'description': 'AI 기반 반려동물 헬스케어 스타트업 십일리터가 AI 기반 반려동물 진행성 질환 홈케어 솔루션 ‘라이펫’으로 삼성전자 ‘C-Lab Outside’ 프로그램에 선정됐다.\nThe post 십일리터 ‘라이펫’, 삼성전자 C-랩 아웃사이드 선정 appeared first on 벤처스퀘어.', 'url': 'https://www.venturesquare.net/956403', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2025/02/lifet-696x522.jpg', 'publishedAt': '2025-02-05T05:35:42Z', 'content': "(AI) ‘’ ( ) C-Lab Outside 5 . 2022, C-Lab Outside .\r\n C-Lab Outside , , , IT .\r\n 3 Vision AI . 1 , , , , . (TTA) 97% . 1 . AI 10 .\r\n AI . . AI API , B2B .\r\n , C-Lab Outside , .\r\n11-liter 'Lifet' sele… [+6448 chars]"}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '배문규 기자 sobbell@kyunghyang.com', 'title': '이재용·올트먼·손정의 회동 후 “좋은 논의”…한·미·일 ‘AI 동맹’ 시동', 'description': '중국 딥시크 공세에 대응 주목\n삼성전자, 스타게이트 합류 땐\n오픈AI에 반도체 공급 가능성\n\n이재용 삼성전자 회장이 샘 올트먼 오픈AI 최고경영자(CEO), 손정의 소프트뱅크그룹 회장(일본명 손 마사요시)과 전격 3자 회동을 하면서 ‘한·미·일 인공지능(AI) 동맹’이 본격화할지 주목된다.\n\n4일 재계에 따르면 이 회장은 이날 삼성전자 서초사옥에···', 'url': 'https://www.khan.co.kr/article/202502042011015', 'urlToImage': 'https://img.khan.co.kr/spko/company/Khan_CI_180212.jpg', 'publishedAt': '2025-02-04T11:11:01Z', 'content': 'AI (CEO), ( ) 3 ·· (AI) .\r\n4 CEO, . 3 , AI, AI .\r\n . 3 . CEO AI .\r\n . AI , 5000 AI AI .\r\n AI .\r\n AI GPT AI (R1) CEO .\r\n CEO . AI, , AI .\r\n AI CEO 1 . ( ) Arm() 10 .\r\n 2 CEO .'}, {'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '강진희', 'title': '엔라이튼, 삼성전자 협력사 RE100 자가용 태양광 공급사업자 선정', 'description': '엔라이튼은 5일 삼성전자의 공식 RE100 자가용 태양광 공급사업자 중 하나로 선정됐다고 밝혔다.\nThe post 엔라이튼, 삼성전자 협력사 RE100 자가용 태양광 공급사업자 선정 appeared first on 벤처스퀘어.', 'url': 'https://www.venturesquare.net/956351', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2025/02/fskjghsjdkf.jpg', 'publishedAt': '2025-02-05T03:35:12Z', 'content': '5 RE100 , . , ( ·) ( ) . . , . . RE100 . , ESG . , RE100 . , .Enlighten, Samsung Electronics Partner RE100 Private Solar Power Supplier Selected \r\nEnergy and climate tech company Enlighten announced … [+4039 chars]'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김나연 기자 nyc@kyunghyang.com', 'title': '이재용 ‘부당합병·불법승계’ 오는 3일 항소심 선고···‘1심 무죄’ 바뀔까', 'description': '이재용 삼성전자 회장이 지난해 11월25일 오후 서울 서초구 서울중앙지법에서 열린 삼성 부당 합병 혐의 관련 2심 공판에 출석하고 있다. 연합뉴스\n\n이재용 삼성전자 회장의 ‘삼성그룹 경영권 불법승계’ 사건 항소심 선고가 오는 3일 나온다. 이 회장은 1심에서 모든 혐의를 무죄로 선고받았는데, 항소심 과정에서 삼성바이오로직스(삼성바이오)의 회계처리 과정에 문···', 'url': 'https://www.khan.co.kr/article/202502021709001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/02/rcv.YNA.20241125.PYH2024112510680001300_P1.jpg', 'publishedAt': '2025-02-02T08:09:00Z', 'content': ', 5 ... \r\n 1 5 5 . 2 3 . 25 13( ) , ...\r\nhttps://www.khan.co.kr/article/202411251652001'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '이창준 기자 jchang@kyunghyang.com', 'title': '검찰, 이재용 ‘부당합병 무죄’ 상고심의위 심의 요청', 'description': '이재용 삼성전자 회장이 지난 3일 서초구 서울고법에서 열린 그룹 경영권 승계 관련 부당합병·회계부정 의혹 항소심 선고공판에서 무죄 판결을 받은 뒤 법원을 나서고 있다. 권도현 기자\n\n검찰이 항소심에서 무죄가 선고된 이재용 삼성전자 회장의 부당합병·회계부정 의혹 사건에 상고하기 위해 외부 전문가 의견을 듣기로 했다.\n\n6일 법조계에 따르면 서울중앙지검 수사팀···', 'url': 'https://www.khan.co.kr/article/202502061835001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/06/news-p.v1.20250203.1956859739864ce1823a723331ca27cc_P1.jpeg', 'publishedAt': '2025-02-06T09:35:00Z', 'content': '3 · . \r\n· .\r\n6 .\r\n 1·2 . 1·2 .\r\n , 5 . . , .\r\n 2015 · , , 2020 9 .\r\n1 19 , 3 .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '강병한 기자 silverman@kyunghyang.com', 'title': '‘관세폭탄 예고’ 캐나다·멕시코에 한국 대기업 해외법인 201곳 운영', 'description': '삼성전자 멕시코 케레타로 공장에서 근로자들이 작업하는 모습. 삼성전자 제공\n\n국내 주요 그룹이 미국 정부가 보편관세를 부과키로 했다가 유예한 캐나다와 멕시코에 200곳이 넘는 해외법인을 운영하는 것으로 조사됐다.\n\n기업분석전문 한국CXO연구소는 공정거래위원회 지정 88개 대기업집단이 캐나다와 멕시코에 세운 해외법인 현황을 조사한 결과, 25개 그룹이 해외 ···', 'url': 'https://www.khan.co.kr/article/202502041142001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/04/rcv.YNA.20240922.PYH2024092200710008700_P1.jpg', ' ...
# {'score': 0.8, 'explanation': "이 기사는 긍정적인 내용을 다루고 있습니다. '라이펫'이 삼성전자 'C-Lab Outside' 프로그램에 선정된 것은 성과로 해석될 수 있습니다."}
# {'score': 0.7, 'explanation': "이 기사는 긍정적인 내용을 다루고 있습니다. 이재용 삼성전자 회장과 올트먼, 손정의 회장의 회동이 '좋은 논의'로 진행되었고, 한·미·일 'AI 동맹'이 본격화될 가능성에 대한 기대가 나타나고 있습니다. 또한, 삼성전자가 오픈AI에 반도체 공급 가능성을 모색하고 있는 것으로 언급되어 긍정적인 분위기를 보여줍니다."}
# {'score': 0.8, 'explanation': '이 기사는 삼성전자와 엔라이튼의 협력을 통한 태양광 사업자 선정 소식을 다루고 있습니다. 긍정적인 협력 소식을 다루고 있어 감성 점수는 0.8로 매우 긍정적입니다.'}
# {'score': -0.7, 'explanation': "이 기사는 이재용 삼성전자 회장의 항소심 선고가 예정된 내용을 다루고 있습니다. 기사 내용은 부정적인 요소가 강하게 나타나고 있으며, '부당합병', '불법승계'와 같은 용어들이 사용되어 있습니다. 또한, 이재용 삼성전자 회장이 1심에서 무죄 판결을 받았지만, 이에 대한 항소심 결과에 대한 불확실성이 언급되어 있습니다."}
# {'score': -0.7, 'explanation': "이 기사는 중립적인 입장으로 작성되었으며, 이재용 삼성전자 회장의 무죄 판결과 검찰의 상고 심의 요청에 대한 사실을 보도하고 있습니다. 그러나 '부당합병·회계부정 의혹'과 같은 부정적인 용어가 사용되어 있어 감성 점수가 부정적으로 평가됩니다."}
# {'score': -0.7, 'explanation': '기사의 내용은 미국 정부의 보편관세 부과로 인해 한국 대기업이 캐나다와 멕시코에 많은 해외법인을 운영하고 있다는 것을 다루고 있습니다. 이는 미국의 무역정책 변화로 인해 기업들이 대응하고 있는 현상을 반영하고 있으며, 경제적인 불안을 암시하고 있습니다. 따라서 감성 점수는 -0.7로 설정됩니다.'}
# {'score': -0.8, 'explanation': '이 기사는 부정적인 감성을 담고 있습니다. 주요 내용은 삼성전자 연구·개발직 노조원의 대다수가 반도체법 52시간 예외 규정에 반대한다는 것으로, 이는 장시간 노동에 대한 우려와 시대착오적인 노동 관행을 버려야 한다는 주장을 반영하고 있습니다.'}
# {'score': 0.8, 'explanation': '이 기사는 송재혁 삼성전자 CTO가 차기 반도체산업협회장으로 내정된 소식을 다루고 있습니다. 이는 긍정적인 소식으로 해석될 수 있으며, 이로 인해 기술 분야에 대한 지속적인 발전이 이루어질 것으로 기대됩니다.'}
# {'score': 0.8, 'explanation': "이 기사는 삼성전자의 신제품 '갤럭시S25'의 글로벌 출시 소식을 다루고 있습니다. 긍정적인 내용이 많이 포함되어 있어 감성 점수가 높게 평가됩니다. 삼성전자의 신제품 출시가 성공적이었고, 사전 판매 신기록을 경신했다는 내용이 긍정적인 요소로 작용했습니다."}
# {'score': 0.8, 'explanation': '이 기사는 삼성전자와 SK하이닉스의 긍정적인 실적과 성장에 대한 내용을 다루고 있습니다. 따라서 긍정적인 감성을 가지고 있습니다.'}
# {'topic': '삼성전자',
#  'average_sentiment': 0.18,
#  'analyzed_articles': 10,
#  'sentiment_summary': '중립적'}

# %%
from typing import List, Dict, Any
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.agents import create_openai_functions_agent
from langchain.agents import AgentExecutor
import requests
import json
from datetime import datetime, timedelta

# 뉴스 감성분석 도구
@tool
def get_news_sentiment(topic: str) -> Dict[str, Any]:
    """특정 주제에 대한 뉴스 기사의 감성을 분석합니다."""

    # NewsAPI 설정
    NEWS_API_KEY = os.getenv("NEWS_API_KEY")
    news_api_url = "https://newsapi.org/v2/everything"

    # 날짜 범위 설정
    end_date = datetime.now()
    start_date = end_date - timedelta(days=7)

    querystring = {
        "q": topic,
        "from": start_date.strftime("%Y-%m-%d"),
        "to": end_date.strftime("%Y-%m-%d"),
        "language": "ko",
        "sortBy": "relevancy",
        "apiKey": NEWS_API_KEY
    }

    try:
        response = requests.get(news_api_url, params=querystring)
        articles = response.json().get('articles', [])

        if not articles:
            return {
                "topic": topic,
                "average_sentiment": 0,
                "analyzed_articles": 0,
                "sentiment_summary": "데이터 없음"
            }

        # 감성 분석을 위한 OpenAI 설정
        llm = ChatOpenAI(
            model="gpt-3.5-turbo",
            temperature=0,
        )

        # 각 기사에 대한 감성 분석
        sentiment_scores = []
        print(articles[:10])
        for article in articles[:10]:  # 최근 10개 기사만 분석
            if article['description'] != '[Removed]':
                prompt = ChatPromptTemplate.from_messages([
                    ("system", "뉴스 기사의 감성을 분석하여 아래와 같은 JSON 형태로 응답하세요. "
                "결과는 'score'는 -1(매우 부정적)에서 1(매우 긍정적) 사이의 값이고, "
                "'explanation'은 해당 감성 점수에 대한 설명을 포함합니다."),
                    ("user", f"제목: {article['title']}\n내용: {article['description']}")
                ])

                chain = prompt | llm
                result = chain.invoke({})
                try:
                    response_json = json.loads(result.content)
                    score = float(response_json['score'])
                    if score != 0:
                        print(response_json)
                    sentiment_scores.append(score)
                except (json.JSONDecodeError, KeyError, ValueError) as e:
                    print(f"Error parsing result: {e}")
                    continue


        # 종합 감성 점수 계산
        if sentiment_scores:
            avg_sentiment = sum(sentiment_scores) / len(sentiment_scores)
            return {
                "topic": topic,
                "average_sentiment": round(avg_sentiment, 2),
                "analyzed_articles": len(sentiment_scores),
                "sentiment_summary": "긍정적" if avg_sentiment > 0.3 else "부정적" if avg_sentiment < -0.3 else "중립적"
            }
        else:
            return {
                "topic": topic,
                "average_sentiment": 0,
                "analyzed_articles": 0,
                "sentiment_summary": "분석 불가"
            }

    except Exception as e:
        return {
            "topic": topic,
            "average_sentiment": 0,
            "analyzed_articles": 0,
            "sentiment_summary": f"에러 발생: {str(e)}"
        }

# 산업군 분석 도구
@tool
def analyze_industry_news(industry: str) -> Dict[str, Any]:
    """특정 산업군에 대한 뉴스를 분석합니다."""
    return get_news_sentiment(f"{industry} industry")

# 경제 지표 분석 도구
@tool
def analyze_economic_indicators(indicators: Dict[str, Any] = None) -> Dict[str, Any]:
    """주요 경제 지표 관련 뉴스를 분석합니다."""
    default_indicators = ["금리", "통화정책", "인플레이션", "GDP"]
    if indicators is None:
        indicators ={"list": default_indicators}
    economic_indicators = indicators.get('list', default_indicators)

    results = {}
    for indicator in economic_indicators:
        results[indicator] = get_news_sentiment(indicator)
    return results

# 투자 결정 도구
@tool
def make_investment_decision(inputs: Dict[str, Any]) -> Dict[str, Any]:
    """
    종합적인 분석을 바탕으로 투자 결정을 제안합니다.
    """

    # 입력 값 추출
    company = inputs.get("company", "Unknown")
    company_sentiment = inputs.get("company_sentiment", {"average_sentiment": 0})
    industry_sentiment = inputs.get("industry_sentiment", {"average_sentiment": 0})
    economic_indicators = inputs.get("economic_indicators", {})

    # 가중치 설정
    weights = {
        "company": 0.4,
        "industry": 0.3,
        "economic": 0.3
    }

    # 회사 점수 계산
    company_score = company_sentiment.get("average_sentiment", 0) * weights["company"]

    # 산업 점수 계산
    industry_score = industry_sentiment.get("average_sentiment", 0) * weights["industry"]

    # 경제 지표 점수 계산
    economic_scores = [
        indicator.get("average_sentiment", 0)
        for indicator in economic_indicators.values()
    ]
    economic_score = (sum(economic_scores) / len(economic_scores)) * weights["economic"] if economic_scores else 0

    # 총점 계산
    total_score = company_score + industry_score + economic_score

    # 투자 결정
    decision = {
        "company": company,
        "timestamp": datetime.now().isoformat(),
        "total_score": round(total_score, 2),
        "recommendation": "매수" if total_score > 0.3 else "매도" if total_score < -0.3 else "관망",
        "confidence": abs(total_score),
        "factors": {
            "company_sentiment": company_sentiment,
            "industry_sentiment": industry_sentiment,
            "economic_indicators": economic_indicators
        }
    }

    return decision

class InvestmentAnalyzer:
    def __init__(self):
        self.llm = ChatOpenAI(
            model="gpt-4",
            temperature=0
        )

        self.tools = [
            get_news_sentiment,
            analyze_industry_news,
            analyze_economic_indicators,
            make_investment_decision
        ]

        prompt = ChatPromptTemplate.from_messages([
            ("system", """주식 시장 분석 및 투자 결정을 돕는 AI 에이전트입니다.
            뉴스 데이터를 수집하고 감성 분석을 통해 투자 결정을 제안합니다."""),
            ("user", "{input}"),
            MessagesPlaceholder(variable_name="agent_scratchpad")
        ])

        self.agent = create_openai_functions_agent(self.llm, self.tools, prompt)
        self.executor = AgentExecutor(agent=self.agent, tools=self.tools, verbose=True)

    def analyze(self, company: str, industry: str) -> Dict[str, Any]:
        """투자 분석을 수행하고 결과를 반환합니다."""
        try:
            # 1. 회사 감성 분석
            company_result = get_news_sentiment(company)

            # 2. 산업군 감성 분석
            industry_result = analyze_industry_news(industry)

            # 3. 경제 지표 분석
            economic_result = analyze_economic_indicators({"list": ["금리"]})

            # 4. 투자 결정
            decision = make_investment_decision({"inputs":{
                    "company": company,
                    "company_sentiment": company_result,
                    "industry_sentiment": industry_result,
                    "economic_indicators": economic_result
                }
            })
            # decision = self.executor.invoke({
            #     "tool": "make_investment_decision",
            #     "input": {
            #         "company": company,
            #         "company_sentiment": company_result,
            #         "industry_sentiment": industry_result,
            #         "economic_indicators": economic_result
            #     }
            # })

            return decision

        except Exception as e:
            print(f"분석 중 오류 발생: {str(e)}")
            return {
                "error": str(e),
                "status": "failed"
            }

if __name__ == "__main__":
    analyzer = InvestmentAnalyzer()

    # 삼성전자 분석 예시
    result = analyzer.analyze(
        company="삼성전자",
        industry="반도체"
    )

    print("\n최종 투자 분석 결과:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# [{'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '오효진', 'title': '십일리터 ‘라이펫’, 삼성전자 C-랩 아웃사이드 선정', 'description': 'AI 기반 반려동물 헬스케어 스타트업 십일리터가 AI 기반 반려동물 진행성 질환 홈케어 솔루션 ‘라이펫’으로 삼성전자 ‘C-Lab Outside’ 프로그램에 선정됐다.\nThe post 십일리터 ‘라이펫’, 삼성전자 C-랩 아웃사이드 선정 appeared first on 벤처스퀘어.', 'url': 'https://www.venturesquare.net/956403', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2025/02/lifet-696x522.jpg', 'publishedAt': '2025-02-05T05:35:42Z', 'content': "(AI) ‘’ ( ) C-Lab Outside 5 . 2022, C-Lab Outside .\r\n C-Lab Outside , , , IT .\r\n 3 Vision AI . 1 , , , , . (TTA) 97% . 1 . AI 10 .\r\n AI . . AI API , B2B .\r\n , C-Lab Outside , .\r\n11-liter 'Lifet' sele… [+6448 chars]"}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '배문규 기자 sobbell@kyunghyang.com', 'title': '이재용·올트먼·손정의 회동 후 “좋은 논의”…한·미·일 ‘AI 동맹’ 시동', 'description': '중국 딥시크 공세에 대응 주목\n삼성전자, 스타게이트 합류 땐\n오픈AI에 반도체 공급 가능성\n\n이재용 삼성전자 회장이 샘 올트먼 오픈AI 최고경영자(CEO), 손정의 소프트뱅크그룹 회장(일본명 손 마사요시)과 전격 3자 회동을 하면서 ‘한·미·일 인공지능(AI) 동맹’이 본격화할지 주목된다.\n\n4일 재계에 따르면 이 회장은 이날 삼성전자 서초사옥에···', 'url': 'https://www.khan.co.kr/article/202502042011015', 'urlToImage': 'https://img.khan.co.kr/spko/company/Khan_CI_180212.jpg', 'publishedAt': '2025-02-04T11:11:01Z', 'content': 'AI (CEO), ( ) 3 ·· (AI) .\r\n4 CEO, . 3 , AI, AI .\r\n . 3 . CEO AI .\r\n . AI , 5000 AI AI .\r\n AI .\r\n AI GPT AI (R1) CEO .\r\n CEO . AI, , AI .\r\n AI CEO 1 . ( ) Arm() 10 .\r\n 2 CEO .'}, {'source': {'id': None, 'name': 'Venturesquare.net'}, 'author': '강진희', 'title': '엔라이튼, 삼성전자 협력사 RE100 자가용 태양광 공급사업자 선정', 'description': '엔라이튼은 5일 삼성전자의 공식 RE100 자가용 태양광 공급사업자 중 하나로 선정됐다고 밝혔다.\nThe post 엔라이튼, 삼성전자 협력사 RE100 자가용 태양광 공급사업자 선정 appeared first on 벤처스퀘어.', 'url': 'https://www.venturesquare.net/956351', 'urlToImage': 'https://www.venturesquare.net/wp-content/uploads/2025/02/fskjghsjdkf.jpg', 'publishedAt': '2025-02-05T03:35:12Z', 'content': '5 RE100 , . , ( ·) ( ) . . , . . RE100 . , ESG . , RE100 . , .Enlighten, Samsung Electronics Partner RE100 Private Solar Power Supplier Selected \r\nEnergy and climate tech company Enlighten announced … [+4039 chars]'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김나연 기자 nyc@kyunghyang.com', 'title': '이재용 ‘부당합병·불법승계’ 오는 3일 항소심 선고···‘1심 무죄’ 바뀔까', 'description': '이재용 삼성전자 회장이 지난해 11월25일 오후 서울 서초구 서울중앙지법에서 열린 삼성 부당 합병 혐의 관련 2심 공판에 출석하고 있다. 연합뉴스\n\n이재용 삼성전자 회장의 ‘삼성그룹 경영권 불법승계’ 사건 항소심 선고가 오는 3일 나온다. 이 회장은 1심에서 모든 혐의를 무죄로 선고받았는데, 항소심 과정에서 삼성바이오로직스(삼성바이오)의 회계처리 과정에 문···', 'url': 'https://www.khan.co.kr/article/202502021709001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/02/rcv.YNA.20241125.PYH2024112510680001300_P1.jpg', 'publishedAt': '2025-02-02T08:09:00Z', 'content': ', 5 ... \r\n 1 5 5 . 2 3 . 25 13( ) , ...\r\nhttps://www.khan.co.kr/article/202411251652001'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '이창준 기자 jchang@kyunghyang.com', 'title': '검찰, 이재용 ‘부당합병 무죄’ 상고심의위 심의 요청', 'description': '이재용 삼성전자 회장이 지난 3일 서초구 서울고법에서 열린 그룹 경영권 승계 관련 부당합병·회계부정 의혹 항소심 선고공판에서 무죄 판결을 받은 뒤 법원을 나서고 있다. 권도현 기자\n\n검찰이 항소심에서 무죄가 선고된 이재용 삼성전자 회장의 부당합병·회계부정 의혹 사건에 상고하기 위해 외부 전문가 의견을 듣기로 했다.\n\n6일 법조계에 따르면 서울중앙지검 수사팀···', 'url': 'https://www.khan.co.kr/article/202502061835001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/06/news-p.v1.20250203.1956859739864ce1823a723331ca27cc_P1.jpeg', 'publishedAt': '2025-02-06T09:35:00Z', 'content': '3 · . \r\n· .\r\n6 .\r\n 1·2 . 1·2 .\r\n , 5 . . , .\r\n 2015 · , , 2020 9 .\r\n1 19 , 3 .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '강병한 기자 silverman@kyunghyang.com', 'title': '‘관세폭탄 예고’ 캐나다·멕시코에 한국 대기업 해외법인 201곳 운영', 'description': '삼성전자 멕시코 케레타로 공장에서 근로자들이 작업하는 모습. 삼성전자 제공\n\n국내 주요 그룹이 미국 정부가 보편관세를 부과키로 했다가 유예한 캐나다와 멕시코에 200곳이 넘는 해외법인을 운영하는 것으로 조사됐다.\n\n기업분석전문 한국CXO연구소는 공정거래위원회 지정 88개 대기업집단이 캐나다와 멕시코에 세운 해외법인 현황을 조사한 결과, 25개 그룹이 해외 ···', 'url': 'https://www.khan.co.kr/article/202502041142001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/04/rcv.YNA.20240922.PYH2024092200710008700_P1.jpg', ' ...
# {'score': 0.8, 'explanation': "이 기사는 긍정적인 내용을 다루고 있습니다. '라이펫'이 삼성전자 C-Lab Outside 프로그램에 선정된 것은 긍정적인 소식이며, AI 기반 반려동물 헬스케어 솔루션에 대한 관심과 성과를 보여줍니다."}
# {'score': 0.7, 'explanation': '이 기사는 긍정적인 내용을 다루고 있습니다. 이재용 삼성전자 회장과 올트먼 오픈AI CEO, 손정의 소프트뱅크그룹 회장이 한·미·일 인공지능(AI) 동맹을 위해 회동했고, 좋은 논의를 했다는 내용이 강조되고 있습니다. 또한, 삼성전자가 오픈AI에 반도체 공급 가능성이 언급되어 긍정적인 분위기를 조성하고 있습니다.'}
# {'score': 0.8, 'explanation': '이 기사는 삼성전자와 엔라이튼의 협력사로 선정된 소식을 다루고 있습니다. 협력사로 선정된 것은 긍정적인 소식이며, 태양광 공급사업에 참여함으로써 환경 친화적인 활동에 기여하는 것으로 해석될 수 있습니다.'}
# {'score': 0.2, 'explanation': '약간 긍정적인 감성을 나타냄. 기사 내용에서 이재용 삼성전자 회장이 1심에서 모든 혐의를 무죄로 선고받은 점이 긍정적인 요소로 작용할 수 있음.'}
# {'score': -0.5, 'explanation': '이 기사는 중립적인 입장을 취하고 있습니다. 검찰이 이재용 삼성전자 회장의 무죄 판결에 대해 상고하기 위해 외부 전문가 의견을 듣기로 한 내용을 다루고 있습니다. 이에 따라 감성 점수는 -0.5로 설정됩니다.'}
# {'score': -0.7, 'explanation': '기사의 내용은 미국 정부의 보편관세 부과로 인해 한국 대기업이 캐나다와 멕시코에 많은 해외법인을 운영하고 있다는 것을 다루고 있습니다. 이는 미국의 무역정책 변화로 인해 기업들이 대응하고 있는 현상을 반영하고 있으며, 경제적인 불안을 암시하고 있습니다. 따라서 이 기사는 부정적인 감성을 담고 있습니다.'}
# {'score': -0.8, 'explanation': '이 기사는 삼성전자 연구·개발직 노조원들이 주 52시간 상한 규제에서 제외되는 것에 반대하는 내용을 다루고 있습니다. 이는 노동자들이 장시간 노동에 대한 우려와 시대착오적인 노동 관행을 버리자는 요구를 반영하고 있습니다. 따라서 부정적인 감성을 가지고 있는 기사입니다.'}
# {'score': 0.8, 'explanation': '이 기사는 송재혁 삼성전자 CTO가 차기 반도체산업협회장으로 내정된 내용을 다루고 있습니다. 이는 긍정적인 소식으로 해석될 수 있습니다.'}
# {'score': 0.8, 'explanation': "이 기사는 삼성전자의 신제품 '갤럭시S25'의 글로벌 출시 소식을 다루고 있습니다. 긍정적인 내용이 많이 포함되어 있어 감성 점수가 0.8로 나왔습니다."}
# {'score': 0.8, 'explanation': '이 기사는 삼성전자와 SK하이닉스의 긍정적인 실적과 성장에 대해 다루고 있습니다. 따라서 긍정적인 감성을 가지고 있습니다.'}
# [{'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '김한준 기자', 'title': '비트코인 9만4천 달러 하회...XRP-도지 등 주요 알트코인 두 자릿수↓', 'description': '[지디넷코리아]비트코인이 크게 하락하며 3일 한때 9만3천 달러 선을 하회했다. 주요 알트코인는 전일대비 두 자릿수 넘는 하락세를 보이며 가상자산 시장에 긴장감이 고조된다.글로벌 가상자산 데이터 플랫폼 코인게코에 따르면 비트코인은 3일 오전 한때 약 9만2천796달러 선까지 하락했다. 이는 지난 24시간 기준 8.1% 하락한 수치다.이후 비트코인은 시세를 회복하며 오전 11시 20분 현재 약 9만4천299달러에 거래 중이다.주요 알트코인 시세도 크게 휘청였다.…', 'url': 'https://zdnet.co.kr/view/?no=20250203103817', 'urlToImage': 'https://image.zdnet.co.kr/2022/05/01/4bb2d162eabcc5e8e04d931133fb919b.jpg', 'publishedAt': '2025-02-03T02:43:14Z', 'content': '3 93 . .\r\n 3 92796 . 24 8.1% .\r\n 11 20 94299 .\r\n(=)\r\n. 20.1% 2482, (XRP) 27.1% 2.12 .\r\n 12.5%, 27.1%, 32.6%, 24.7% .\r\n .\r\n 25%, 10% 2 1 .\r\n " " .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '류덕현 중앙대 경제학부 교수', 'title': '[경제직필]국가신용등급 추락 피할 수 있을까?', 'description': '국가신용등급은 단순한 숫자가 아니다. 이는 한 나라의 경제 신뢰도를 나타내며, 투자자들에게 중요한 신호로 작용한다. 신용등급이 낮아지면 국채 금리 상승, 외국인 자금 유출, 기업과 금융기관의 대출 비용 증가로 이어지며, 이는 정부 재정 부담 증가와 경제 성장 둔화를 초래할 수 있다. 한국은 1997년 외환위기 당시 신용등급이 대폭 하락한 이후 꾸준한 경제 ···', 'url': 'https://www.khan.co.kr/article/202502042115005', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/04/l_2025020501000088200011481.jpg', 'publishedAt': '2025-02-04T12:15:00Z', 'content': '. , . , , , . 1997 . AA( 18, 13.6%), Aa2( 15, 10.5%), AA-( 20, 16.3%) . 2016 .\r\n , . . 2025 120 . 2 · FTA , ·· , 8 . .\r\n , . (Voice and Accountability) (Rule of Law) , . , . , 18 (Aa2 ) 2 . . , .\r\n ,… [+101 chars]'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '방은주 기자', 'title': '뱅크몰, \'2024 데이터 리포트\' 공개···"주택담보대출 이자 639만원 절감"', 'description': '[지디넷코리아] 주택담보대출 금리비교 플랫폼 뱅크몰은 작년 한 해 동안 누적된 자사 대출 비교 서비스 이용자의 대출 비교 이용 패턴과 서비스 이용으로 발생한 고객 편익 등에 대한 보고서를 마련, 공개했다고 3일 밝혔다..뱅크몰은 2022년 국내 최초 주택담보대출 전문 비교 플랫폼을 출범, 현재까지 700만 명이 넘는 누적 이용자를 달성했고, 국내 대출 비교 플랫폼 중 가장 많은 227개의 금융사와 제휴를 맺어 상품을 중개하고 있다. 대출 비교 서비스를 이용한 …', 'url': 'https://zdnet.co.kr/view/?no=20250203120100', 'urlToImage': 'https://image.zdnet.co.kr/2022/01/24/6d1797efd7dd4e094b4271e137083a9f.jpg', 'publishedAt': '2025-02-03T03:01:00Z', 'content': ', 3 ..\r\n 2022 , 700 , 227 . 930 , 368 .\r\n 2.74%, 2 3306 1 639 . 20.0% 4.25% 15.75% .\r\n 4 . , , . 52 , 17 . 1 1 , 16.8 .\r\n\xa0 7 · . , , . 4, 2 8 .\r\n TV , , , . 420 , 856 . .\r\n " . " " . .\r\n , , , .'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '손희연 기자', 'title': '신한은행 "법인 대출도 비교해보세요"', 'description': "[지디넷코리아]신한은행이 법인 전용 대출비교 플랫폼인 '론앤비즈(Loan&Biz)'와 전용 홈페이지를 오픈했다고 5일 밝혔다.론앤비즈는 법인사업자 고객을 대상으로 신용·담보대출, 기계기구 리스 등을 한번에 확인하고 신청할 수 있다.신한은행은 물론이고 저축은행 9곳, 캐피탈 5곳, 개별 신협 241군데가 참여했다.법인 고객들은 별도의 공식 홈페이지에 접속해 고객정보 등록 및 법인 본인 확인 절차를 거친 후 자금용도에 맞는 대출비교를 신청할 수 있으며, 제휴 금융…", 'url': 'https://zdnet.co.kr/view/?no=20250205101212', 'urlToImage': 'https://image.zdnet.co.kr/2025/02/05/b1d595abca169cebb7e811055f62f688.png', 'publishedAt': '2025-02-05T01:17:55Z', 'content': "'(Loan&amp;Biz)' \xa0 5 .\r\n ·, \xa0 .\r\n 9, 5, 241 .\r\n, .\r\n 6 .\r\n · .\xa0\r\n , .\r\n 0.2% 100( ), 0.5% 300( ) .\r\n .\r\n 4 SOL . 9 3 2, 470 ."}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '손희연 기자', 'title': '[미장브리핑] UBS "금, 불확실성서 사상 최고치 경신할 것"', 'description': '[지디넷코리아]◇ 6일(현지시간) 미국 증시▲다우존스산업평균(다우)지수 전 거래일 대비 0.28% 하락한 44747.63.▲스탠다드앤푸어스(S&P)500 지수 전 거래일 대비 0.36% 상승한 6083.57.▲나스닥 지수 전 거래일 대비 0.51% 상승한 19791.99.▲1월 고용 보고서 대기. 다우존스 조사에 따르면 1월 비농업 고용은 이번 달 16만9천명 증가 예측. 12월에는 25만5천개 늘어.▲지난 주 미국 실업 수당 신청 건수 21만9천건으로 예상보…', 'url': 'https://zdnet.co.kr/view/?no=20250207081512', 'urlToImage': 'https://image.zdnet.co.kr/2023/12/18/55c42605632d9290c257ceee36bc5656.jpg', 'publishedAt': '2025-02-06T23:15:12Z', 'content': '6() \r\n() 0.28% 44747.63.\r\n(S&amp;P)500 0.36% 6083.57.\r\n 0.51% 19791.99.\r\n(=)\r\n1 . 1 169 . 12 255 .\r\n 219 . 11 214 .\xa0\r\n UBS . UBS 12 3 . 5 2882.16 .\xa0UBS CNBC " , 30% " " , , " .\xa0\r\n . PVH . , . 9 PVH\xa0 .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '윤지호 경제평론가', 'title': '[윤지호의 투자, 함께 고민하시죠]2025 경기 침체 ...
# {'score': -0.8, 'explanation': '주요 가상자산인 비트코인과 알트코인들이 큰 폭으로 하락하며 시장에 긴장감이 고조되고 있다는 내용으로 매우 부정적인 감성을 나타냅니다.'}
# {'score': -0.8, 'explanation': '주어진 텍스트는 국가신용등급이 낮아질 경우의 부정적인 영향을 다루고 있습니다. 따라서 감성 점수는 -0.8로 설정됩니다.'}
# {'score': 0.8, 'explanation': '이 기사는 긍정적인 내용을 다루고 있습니다. 주택담보대출 이자를 절감할 수 있는 정보를 제공하는 등 고객에게 혜택을 주는 내용이 포함되어 있습니다.'}
# {'score': 0.7, 'explanation': '이 기사는 긍정적인 내용을 다루고 있습니다. 신한은행이 법인 대출에 대한 비교 플랫폼을 오픈하여 고객들에게 편의를 제공하고 있다는 내용으로, 긍정적인 반응을 얻을 수 있습니다.'}
# {'score': 0.7, 'explanation': '이 기사는 긍정적인 내용을 다루고 있습니다. UBS가 금 시장에 대해 사상 최고치를 경신할 것이라는 긍정적 전망을 제시하고 있으며, 미국 증시의 상승과 고용 시장의 호조를 언급하고 있습니다.'}
# {'score': -0.7, 'explanation': '주제와 내용이 부정적이며, 불확실한 경제 상황과 부진한 주가에 대한 언급이 있습니다. 또한 추가경정예산을 요구하는 상황을 설명하고 있어 부정적인 감성을 가지고 있습니다.'}
# {'score': 0.6, 'explanation': '위 기사는 SKIET의 실적 회복에 대한 긍정적인 내용을 다루고 있습니다. 따라서 감성 점수는 0.6으로, 어느 정도 긍정적인 내용을 담고 있습니다.'}
# {'score': 0.8, 'explanation': '가상자산 시장에 대한 긍정적인 전망과 변화에 대한 설명이 주를 이루고 있습니다. 규제 완화를 통한 시장 성장 촉진 등 긍정적인 측면이 강조되어 있어 0.8의 긍정적인 감성 점수를 부여합니다.'}
# [{'source': {'id': None, 'name': 'Kbench.com'}, 'author': 'godbless', 'title': "닌텐도 사장, 차기 '스위치 2' 소비자가 기대하는 저렴한 가격에 출시", 'description': '닌텐도가 차기 스위치 2 가격을 소비자가 기대하는 저렴한 가격에 \n출시할 것이라고 밝혔다.\n후루카와 슌타로 닌텐도 사장은 최근 실적 발표 후 가진 질의응답 \n자리에서 "고객이 닌텐도 제품에 기대하는 저렴한 가격에 집중하고 있지만, \n일본의 인플레이션 증가와 해외의 다른 경제적 요인, 특히 미국 관세의 잠재적 영향을 \n고려해야 한다"고 대답했다. \n닌텐도 사장은 구체적으로 출시 가격은 언급하지 않았지만, 업계에서는 \n차기 스위치가 400달러 대에 출시될 가능성이…', 'url': 'https://kbench.com/?q=node/264428', 'urlToImage': None, 'publishedAt': '2025-02-06T07:19:06Z', 'content': '<td>\r\n</td>'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '손희연 기자', 'title': '[미장브리핑] 美, 멕시코 관세 부과 한 달 유예…나스닥 1.20% 하락', 'description': '[지디넷코리아]◇ 3일(현지시간) 미국 증시▲다우존스산업평균(다우)지수 전 거래일 대비 0.28% 하락한 44421.91.▲스탠다드앤푸어스(S&P)500 지수 전 거래일 대비 0.76% 하락한 5994.57.▲나스닥 지수 전 거래일 대비 1.20% 하락한 19391.96.▲도널드 트럼프 대통령이 캐나다와 멕시코에 25%의 관세를 부과하기로 한 이후 주식 매도세였으나, 트럼프 대통령이 멕시코에 대한 관세를 한 달 연기하기로 하면서 반등.클라우디아 셰인바움 멕시코…', 'url': 'https://zdnet.co.kr/view/?no=20250204080444', 'urlToImage': 'https://image.zdnet.co.kr/2022/06/09/8e8a0ae0afd0f72c3ab2bb42c516230e.jpg', 'publishedAt': '2025-02-03T23:04:44Z', 'content': '3() \r\n() 0.28% 44421.91.\r\n(S&amp;P)500 0.76% 5994.57.\r\n 1.20% 19391.96.\r\n(=)\r\n25% , .\r\n (SNS) . 1 .\xa0\r\n 20 (VIX) 18 .\r\n . " 3~4 " "(PCE) 2.9~3.2%, (GDP) 1.2~1.6% " .\r\n S&amp;P500 CNBC . " " " 2~3% , "… [+125 chars]'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '손희연 기자', 'title': '경상수지 흑자 규모 12월 중 역대 최고치…"中 딥시크 위기이자 기회"', 'description': '[지디넷코리아]수출과 배당 소득 등이 11월 대비 증가하면서 경상수지 흑자 규모가 12월 중 역대 최고치로 집계됐다.6일 한국은행은 2024년 12월 국제수지 잠정치 발표를 통해 12월 경상수지는 123억7천만달러로 11월 흑자 규모 100억5천만달러 대비 23% 가량 증가했다고 밝혔다.작년 12월 경상수지 흑자 규모를 이끈 것은 상품수지와 본원소득수지다. 12월 수출은 633억달러로 11월 수출 569억9천만달러 대비 11% 가량 증가했으며 전년 동월 대비 …', 'url': 'https://zdnet.co.kr/view/?no=20250206092739', 'urlToImage': 'https://image.zdnet.co.kr/2025/02/06/f9476e1079252e10dcfcd2c2784e282a.png', 'publishedAt': '2025-02-06T00:45:53Z', 'content': '11 12 .\r\n6 2024 12 12 1237 11 1005 23% .\r\n 12 .\xa0\r\n(=)\r\n12 633 11 5699 11% 6.6% . IT . 12 37%, 30.6% .\r\n12 5287 11 4711 12.2% ,\xa0 4.2% .\r\n 11 241 12 476 . 11 98 12 359 266% .\r\n .\xa0\r\n 1 " · , " " " .\xa0\r\n … [+33 chars]'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '김한준 기자', 'title': '나홀로 잠잠한 P2E 시장...반등 키워드는 게임성과 수익모델', 'description': '[지디넷코리아]가상자산 시장이 최근 다양한 섹터에서 성장세를 보이고 있지만 P2E 키워드는 좀처럼 반등의 기미를 보이지 않고 있다. 1세대 P2E 게임으로 불리는 엑시 인피니티 이후 이렇다 할 성공 사례를 찾기 어려운 가운데 국내외 규제 환경 역시 개선될 조짐이 보이지 않으면서 업계의 기대감도 점차 낮아지고 있다.최근 가상자산 시장은 비트코인(BTC)의 강세와 함께 다양한 섹터에서 성장을 보이고 있다. 특히, NFT 시장은 디지털 아트, 게임 내 아이템, 멤버…', 'url': 'https://zdnet.co.kr/view/?no=20250207103416', 'urlToImage': 'https://image.zdnet.co.kr/2022/03/30/7efc704ba939269670a32b88806d28a7.jpg', 'publishedAt': '2025-02-07T01:37:55Z', 'content': 'P2E\xa0 .\xa0\r\n1 P2E \xa0 .\r\n (BTC) .\xa0\r\n=\r\n, NFT , , RWA\xa0 , . 2 .\r\n P2E . 2021 .\xa0\r\n P2E . P2E .\r\n . (= )\r\nP2E . , P2E . P2E , .\r\n P2E .\xa0\r\n(EU) (MiCA)\xa0 P2E .\r\n \xa0P2E . P2E . P2E .\r\nMiCA \r\nP2E . P2E , .\xa0\r\n , P2E… [+107 chars]'}, {'source': {'id': None, 'name': 'Ohmynews.com'}, 'author': '이영광', 'title': '"트럼프-김정은 만나도 의미 있는 합의 나오기 어려워"', 'description': '지난 1월 도널드 트럼프 대통령이 미국 47대 대통령으로 취임했다. 트럼프 대통령은 대선 후보 시절부터 김정은 북한 국무 위원장과 친분을 과시했다. 때문에 트럼프 대통령에 기대를 거는 사람도 있었다.\n\n보도에 따르면 트럼프 대통령은 취임식 직후 기자와 질의응답 과정에서 북한을 핵보유국으로 인정하는 듯한 발언을 했다. 이와 관련해 지난 1월 31일 박원곤 이화여대 북한학과 교수와 전화 인터뷰를 했다. 다음은 박 교수와 나눈 일문일답을 정리한 내용이다.\n\n트럼프의…', 'url': 'https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003100442', 'urlToImage': 'https://ojsfile.ohmynews.com/BIG_IMG_FILE/2019/0228/IE002463371_BIG.jpg', 'publishedAt': '2025-02-02T08:56:04Z', 'content': '1 47 . . .. 1 31 . .\r\n- 21 . ?" 1 . 1 . .\r\n. . , 4 . . .\r\n. \' \'(America Is Back) . . , \' \' . . 6 . 6 , , ."\r\n- ?\r\n"6 . , , , , . ? \' \' .\r\n. ? , .\r\n. . \' () \' . , ."\r\n- . ?\r\n". . \' \' , \' \' . . \' \', \' … [+475 chars]'}]
# {'score': 0.7, 'explanation': "이 기사는 닌텐도가 차기 '스위치 2'를 소비자가 기대하는 저렴한 가격에 출시할 것이라는 긍정적인 소식을 전하고 있습니다. 또한, 닌텐도 사장이 고객들의 기대에 대해 인식하고 있고, 경제적 요인들을 고려하고 있다는 내용도 긍정적으로 해석될 수 있습니다."}
# {'score': -0.7, 'explanation': '주식시장이 멕시코에 대한 관세 부과로 하락하였으나, 관세 부과가 한 달 연기된 소식에 반등하였지만 여전히 부정적인 영향을 받고 있는 상황입니다.'}
# {'score': 0.8, 'explanation': '이 기사는 경제 지표인 경상수지 흑자 규모가 역대 최고치를 기록했다는 긍정적인 내용을 다루고 있습니다. 따라서 긍정적인 감성을 가지고 있습니다.'}
# {'score': -0.7, 'explanation': '주제와 내용에서는 P2E 시장이 반등하지 못하고 규제 환경도 개선되지 않아 업계의 기대감이 낮아지고 있다는 부정적인 내용이 주를 이루고 있습니다. 따라서 감성 점수는 -0.7로 설정됩니다.'}
# {'score': -0.7, 'explanation': '이 기사는 중립적인 입장을 취하고 있으며, 트럼프-김정은 만남에 대한 긍정적인 기대보다는 합의가 어려울 것이라는 부정적인 전망을 제시하고 있습니다. 따라서 감성 점수는 -0.7로 설정됩니다.'}
# [{'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김윤나영 기자 nayoung@kyunghyang.com', 'title': '한국 1인당 GDP 계속 올라도…지갑은 변함없네', 'description': '1년 새 1.28% 늘어 작년 3만6000달러 돌파…일본·대만보다 높아\n수출 증가 등 영향…노동자 평균임금은 GDP 대비 850만원 적어\n\n\n\n지난해 한국의 1인당 국내총생산(GDP)이 3만6000달러를 넘어섰다. 일본·대만보다 높은 수치다. 다만 1인당 GDP는 수출 증가 등으로 커진 경제 규모가 반영된 수치라 실제 ‘국민 소득’과는 괴리가 있다···', 'url': 'https://www.khan.co.kr/article/202502022046035', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/02/l_2025020301000019600003071.jpg', 'publishedAt': '2025-02-02T11:46:03Z', 'content': '1 (GDP) 36000 . · . 1 GDP .\r\n2 ·· , 1 GDP 1 454(1.28%) 36024( 5250) . (33234), (32859) .\r\n 1 GDP 19 2021 37503 . 1 GDP 2016(3839) 3 , 2018 35359 19 2020 33503 . 2021 37503 2022 34810 .\r\n 1 GDP GDP . … [+253 chars]'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김윤나영 기자 nayoung@kyunghyang.com', 'title': '1인당 GDP는 일본·대만보다 높은데···내 월급은 왜 그대로?', 'description': '지난 1일 부산항 신선대부두에 수출입 화물이 쌓여있다. 연합뉴스\n\n지난해 한국의 1인당 국내총생산(GDP)이 3만6000달러를 넘어섰다. 일본·대만보다 높은 수치다. 1인당 GDP는 수출 증가 영향 등으로 오른 터라 실제 국민 소득과는 괴리가 있다.\n\n2일 기획재정부·한국은행·통계청 자료를 종합하면, 지난해 1인당 GDP는 1년보다 454달러(1.28%) ···', 'url': 'https://www.khan.co.kr/article/202502021348001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/02/rcv.YNA.20250201.PYH2025020100650005100_P1.jpg', 'publishedAt': '2025-02-02T04:48:00Z', 'content': '1 . \r\n1 (GDP) 36000 . · . 1 GDP .\r\n2 ·· , 1 GDP 1 454(1.28%) 36024( 5250) . (32859), (33234) .\r\n 1 GDP 19 2021 37503 . 1 GDP 2016 3839 3 , 2018 35359 19 2020 33503 . 2021 37503 2022 34810 . 2023 2 , … [+314 chars]'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '조문희 기자 moony@kyunghyang.com', 'title': '트럼프 빠진 경제 협력체 ‘우후죽순’…미국, 무역서 왕따 되나', 'description': 'EU, 남미·스위스 등과 협정\n인도네시아는 브릭스 가입\n영국, EU와 관계 개선 나서\n\n‘미국 우선주의’를 표방한 도널드 트럼프 미국 대통령의 관세 압력이 미국을 제외한 경제 협력체 확산이라는 풍선효과를 낳고 있다는 분석이 제기됐다.\n\n뉴욕타임스(NYT)는 3일(현지시간) “미국의 가장 가까운 동맹국을 포함한 많은 국가가 미국 없이 독자적인 경제···', 'url': 'https://www.khan.co.kr/article/202502042036035', 'urlToImage': 'https://img.khan.co.kr/spko/company/Khan_CI_180212.jpg', 'publishedAt': '2025-02-04T11:36:03Z', 'content': '.\r\n(NYT) 3() . , .\r\nNYT (EU) 3 . EU 12 () 25 (FTA) (GDP) 25% . , 17 25 .\r\n() · (BRICS) 10 . , GDP 40% .\r\n 12 · (CPTPP) , 2020 () EU . 5 EU .\r\nNYT · , 19 , · .\r\n (PIIE) , . ( ) .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김경민 기자 kimkim@kyunghyang.com', 'title': '미국의 8번째 무역적자국 ‘한국’…트럼프 다음 타깃 되나', 'description': '대미 흑자, 캐나다보다 많아\n중국처럼 10% 관세 부과 땐\nGDP 8조원 감소 등 ‘악영향’\n\n저가제품 수출·기술 공세 등 \n중국 대응 행보도 악재 전망\n\n미국이 3대 교역국인 캐나다·멕시코·중국에 대한 관세 부과 절차에 돌입하면서 한국 경제도 본격적인 ‘관세전쟁’의 영향권에 들어가게 됐다. 미국이 무역협정을 뒤집고 동맹국을 상대로 관세···', 'url': 'https://www.khan.co.kr/article/202502030600035', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/03/l_2025020301000027500003391.jpg', 'publishedAt': '2025-02-02T21:00:03Z', 'content': ', 10% GDP 8 \r\n · \r\n 3 ·· . . .\r\n 1() 25% · 10% 40% . 2 2 1 (1.6~3.1%) . .\r\n . .\r\n (11 ) 602( 88) . (674), (626) , (548) . , . 26 · 25% 10% , 10.2% (GDP) 8, 13 .\r\n . . .\r\n . 31 · 21.4 1452.7 . () .\r\n .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '조문희 기자 moony@kyunghyang.com', 'title': '트럼프발 관세 위협 ‘풍선효과’···‘미국 배제’ 경제 블록 확산', 'description': '3일(현지시간) 도널드 트럼프 미국 대통령이 워싱턴 DC 백악관 집무실(오벌 오피스)에 자리해 있다. AP연합뉴스\n\n‘미국 우선주의’를 표방한 도널드 트럼프 미국 대통령의 관세 압력이 미국을 제외한 경제 협력체 확산이라는 풍선효과를 낳고 있다는 분석이 제기됐다.\n\n미 일간 뉴욕타임스(NYT)는 3일 “미국의 가장 가까운 동맹국을 포함한 많은 국가들이 미국 ···', 'url': 'https://www.khan.co.kr/article/202502041612001', 'urlToImage': 'https://img.khan.co.kr/news/2025/02/04/rcv.YNA.20250204.PAP20250204036601009_P1.jpg', 'publishedAt': '2025-02-04T07:12:00Z', 'content': '3() DC ( ) . AP\r\n.\r\n (NYT) 3 .\r\n . · 25% , 10% . (EU) .\r\nNYT EU 2 3 . EU 12 (·MERCOSUR) 25 (FTA) (GDP) 25% . , 17 25 .\r\n() , , (EU) , , 3() EU . AP\r\n(ASEAN·) · (BRICS) 10 . , GDP 40% . · . 5 10 (GCC)… [+76 chars]'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '김양균 기자', 'title': '‘계엄쇼크’에 7조3000억원 증발', 'description': '[지디넷코리아]12·3비상계엄 ...
# {'score': 0.2, 'explanation': '이 기사는 한국의 1인당 GDP가 상승했지만, 노동자 평균임금이 여전히 낮다는 내용을 다루고 있습니다. 따라서 중립적인 감성을 가지고 있습니다.'}
# {'score': -0.7, 'explanation': '이 기사는 경제적인 측면에서의 부정적인 내용을 다루고 있습니다. 1인당 GDP가 높아졌지만 국민 소득은 그에 비례하지 않는다는 문제를 제기하고 있습니다.'}
# {'score': -0.7, 'explanation': "이 기사는 미국의 경제 협력체에서 트럼프 대통령의 영향력이 약화되고 다른 국가들이 독자적인 경제 협력을 강화하고 있다는 내용을 다루고 있습니다. 이는 부정적인 측면이 강하게 나타나는데, 트럼프 대통령의 '미국 우선주의'가 다른 국가들과의 협력을 저해하고 있다는 시각을 반영하고 있습니다."}
# {'score': -0.8, 'explanation': '이 기사는 미국과 한국 간의 무역적자와 관세전쟁에 대한 내용을 다루고 있습니다. 내용이 부정적인 경향을 띄고 있으며, 미국의 관세 부과로 한국 경제에 부정적인 영향을 미칠 것으로 예상하고 있습니다. 따라서 감성 점수는 -0.8로 설정됩니다.'}
# {'score': -0.7, 'explanation': '이 기사는 트럼프 대통령의 관세 압력으로 인해 미국을 제외한 경제 협력체가 확산되고 있다는 내용을 다루고 있습니다. 이는 부정적인 측면이 강하게 작용하고 있으며, 미국의 경제적 영향력이 약화되고 있다는 것을 시사합니다.'}
# {'score': -0.8, 'explanation': "기사 내용은 경제적 손실과 성장률 하락에 대한 내용으로 매우 부정적인 감성을 담고 있습니다. '계엄쇼크'로 인한 7조3천억원의 경제적 손실과 성장률 하락이 주요 이슈로 다뤄지고 있습니다."}
# {'score': -0.8, 'explanation': "이 기사는 정부의 예산안 처리에 대한 부정적인 상황을 다루고 있습니다. '하원 패싱' 결정과 좌파 야당의 반발, 그리고 정부 불신임안 제출 등의 내용으로 인해 부정적인 감정이 느껴집니다."}
# {'score': -0.8, 'explanation': '이 기사는 부정적인 감성을 담고 있습니다. 트럼프 대통령의 새로운 관세 정책이 세계 경제에 충격을 주고 있다는 내용과 글로벌 전자상거래 시장에 대한 우려가 표현되어 있습니다. 또한, 관세 부과 대상과 관련된 내용들이 부정적인 영향을 줄 것으로 예상되는 분위기를 전달하고 있습니다.'}
# {'score': -0.7, 'explanation': '이 기사는 미국 증시의 하락과 관세 부과에 대한 내용을 다루고 있습니다. 뉴스의 내용은 부정적인 요소가 많이 포함되어 있어 감성 점수가 -0.7로 나왔습니다.'}
# {'score': 0.8, 'explanation': '이 기사는 한국의 GDP가 상승하고 있음을 다루고 있습니다. 따라서 긍정적인 감성을 가지고 있습니다.'}
#
# 최종 투자 분석 결과:
# {
#   "company": "삼성전자",
#   "timestamp": "2025-02-08T03:32:34.985054",
#   "total_score": 0.08,
#   "recommendation": "관망",
#   "confidence": 0.08149999999999999,
#   "factors": {
#     "company_sentiment": {
#       "topic": "삼성전자",
#       "average_sentiment": 0.29,
#       "analyzed_articles": 10,
#       "sentiment_summary": "중립적"
#     },
#     "industry_sentiment": {
#       "topic": "반도체 industry",
#       "average_sentiment": 0,
#       "analyzed_articles": 0,
#       "sentiment_summary": "데이터 없음"
#     },
#     "economic_indicators": {
#       "금리": {
#         "topic": "금리",
#         "average_sentiment": 0.16,
#         "analyzed_articles": 8,
#         "sentiment_summary": "중립적"
#       },
#       "통화정책": {
#         "topic": "통화정책",
#         "average_sentiment": 0,
#         "analyzed_articles": 0,
#         "sentiment_summary": "데이터 없음"
#       },
#       "인플레이션": {
#         "topic": "인플레이션",
#         "average_sentiment": -0.12,
#         "analyzed_articles": 5,
#         "sentiment_summary": "중립적"
#       },
#       "GDP": {
#         "topic": "GDP",
#         "average_sentiment": -0.5,
#         "analyzed_articles": 10,
#         "sentiment_summary": "부정적"
#       }
#     }
#   }
# }

# %% [markdown]
# 단순 금리에 대한 뉴스만 불러올 경우 아래 코드 활용 가능

# %%
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.agents import AgentExecutor, initialize_agent, Tool
import requests
import json

@tool()
def get_news_sentiment(topic:str) -> str:
    """주제와 관련된 뉴스 기사의 감성어를 가져와 분석"""
    news_api_url = "https://newsapi.org/v2/everything"
    querystring = {"q": topic, "apiKey": os.getenv('NEWS_API_KEY')}

    response = requests.get(news_api_url, params=querystring)
    articles = response.json().get('articles', [])
    print(articles)

    # 간단한 감정 분석 예시
    sentiment_score = sum(1 if "positive" in article['description'].lower() else -1 for article in articles)
    return f"Sentiment score for {topic}: {sentiment_score}"

tools = [get_news_sentiment]

llm = ChatOpenAI(
    model="gpt-4",
    temperature=0
)

prompt = ChatPromptTemplate.from_messages([
    ("system", """주식 시장 분석 및 투자 결정을 돕는 AI 에이전트입니다.
    뉴스 데이터를 수집하고 감성 분석을 통해 투자 결정을 제안합니다."""),
    ("user", "{input}"),
    MessagesPlaceholder(variable_name="agent_scratchpad")
])

agent = create_openai_functions_agent(llm, tools, prompt)


agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=True,
    handle_parsing_errors=True
)

# 주가 예측 시나리오
response = agent_executor.invoke({"input": "오늘 금리에 대해 감정 분석을 알려줘"})
result = response['output']
print(result)
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `get_news_sentiment` with `{'topic': '금리'}`
#
#
# [{'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김지혜 기자 kimg@kyunghyang.com', 'title': '미 연준의 ‘금리 동결’…한은은 언제 내릴까?', 'description': '미국 연방준비제도(연준)이 1월 정책금리를 동결하고 금리 인하를 서두르지 않겠다는 입장을 밝히면서 한국은행도 금리인하 속도를 늦출 것으로 전망된다. 당장 2월에는 금리를 내리더라도 이후 추가 인하를 결정하기는 어려워 보인다.\n\n미 연준은 지난 28~29일(현지시간) 공개시장위원회(FOMC)에서 정책금리를 연 4.25~4.50%로 동결했다. 연준은 이날 성명···', 'url': 'https://www.khan.co.kr/article/202501301658001', 'urlToImage': 'https://img.khan.co.kr/news/2025/01/30/news-p.v1.20250130.9c98b0a15f4940e8b5060ba64abe4f8b_P1.jpg', 'publishedAt': '2025-01-30T07:58:00Z', 'content': '() 1 . 2 .\r\nmp0131s???????????????\r\n28~29() (FOMC) 4.25~4.50% . 2% .\r\n . . 4 2 .\r\n 25 () . .\r\n , . 20 12·3 1.9% 1.6~1.7% . 1.5% 1.4%, JP 1.3% 1.2% .\r\n22 . \r\n.\r\n (3.00%) (4.25~4.50%) 1.50% . 2.75% 1.7… [+53 chars]'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '임지선 기자 vision@kyunghyang.com', 'title': '[속보] 한은 금통위, 연 3% 금리 동결', 'description': '이창용 한국은행 총재가 16일 오전 서울 중구 한국은행에서 열린 금융통화위원회에서 의사봉을 두드리고 있다. 사진공동취재단\n\n한국은행 금융통화위원회가 연 3%의 현재 금리 수준을 유지하기로 16일 결정했다.\n\n금통위는 이날 오전 서울 중구 한국은행에서 금통위 정례회의를 열고 이같이 결정했다.\n\n금통위는 경기 부양과 물가·금융안정 가운데 물가와 금융안정을 택한···', 'url': 'https://www.khan.co.kr/article/202501160950011', 'urlToImage': 'https://img.khan.co.kr/news/2025/01/16/rcv.YNA.20250116.PYH2025011602790001300_P1.jpg', 'publishedAt': '2025-01-16T00:50:01Z', 'content': '16 . \r\n3% 16 .\r\n .\r\n · .\r\n 12·3 · 1460~1470 . (Fed·) .\r\n 1.5%.'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김지혜 기자 kimg@kyunghyang.com', 'title': '금감원, “일본은행 금리 인상, 엔 캐리 청산 유인 낮아”', 'description': '이복현 금융감독원 원장이 24일 금감원에서 금융상황 점검회의를 주재하고 있다. 금감원 제공\n\n금융감독원은 일본은행 금리 인상과 관련한 시장 일각의 우려와 달리 엔 캐리 트레이드 청산 가능성은 낮다고 진단했다.\n\n금감원은 24일 이복현 원장 주재로 금융상황 점검 회의를 열고 이같이 밝혔다.\n\n금감원은 “시장 일부에서는 지난해 일본은행의 금리인상 후 발생한 ···', 'url': 'https://www.khan.co.kr/article/202501241438001', 'urlToImage': 'https://img.khan.co.kr/news/2025/01/24/news-p.v1.20250124.b53fa4e8f626447a8cdc4a4efe7df359_P1.png', 'publishedAt': '2025-01-24T05:38:00Z', 'content': '24 . \r\n.\r\n 24 .\r\n , .\r\n 0.25% 0.5% .\r\n , .\r\n 7 , · , .\r\n .\r\n (Fed·) (ECB) , .'}, {'source': {'id': None, 'name': 'Zdnet.co.kr'}, 'author': '손희연 기자', 'title': '금리 인하에도 저축은행·부동산신탁 \'흐림\'…"부동산 침체 영향"', 'description': '[지디넷코리아]금리 하락에도 불구하고 부동산 경기 침체로 새해 저축은행과 부동산신탁업권의 전망은 여전히 흐릴 것이라는 관측이 나왔다.7일 오후 열린 한국신용평가 \'2025 금융부문 전망\' 세미나에서 금리 하락으로 조달금리가 인하돼 저축은행과 부동산신탁에게는 긍정적일 순 있지만, 부동산 경기 침체가 가져올 타격이 더 클 수 있다고 진단했다.한국신용평가 정호준 금융·구조화평가본부 애널리스트는 "부동산 경기 침체로 부동산 프로젝트파이낸싱(PF)은 사업성이 낮은 본P…', 'url': 'https://zdnet.co.kr/view/?no=20250107140740', 'urlToImage': 'https://image.zdnet.co.kr/2024/04/29/93e0e64afdd9a79375a4e016e21342d6.jpg', 'publishedAt': '2025-01-07T06:53:58Z', 'content': '.\r\n7 \'2025 \' , .\r\n · " (PF) PF " " " .\r\n(=)\r\nPF 52% PF 88% · . PF 74% .\r\n . " " . .\r\n \xa0" , "\xa0" " .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': 'KyungHyangSinmun', 'title': '[사설]경기·고용 한파에도 금리 동결, 더 시급해진 추경', 'description': '한국은행 금융통화위원회가 16일 기준금리를 연 3.0%로 동결했다. 원·달러 환율이 1450원을 넘는 고환율 속에서 기준금리를 내리면 미국과의 금리 격차가 더 벌어져 원화 약세를 부추길 우려가 크다는 것이다. 경기 침체 속에서도 중앙은행의 통화정책에 기댈 수 없게 된 정부는 추가경정예산 등 적극적인 재정 정책을 서둘러야 한다.\n\n금통위는 금리 동결 후 “예···', 'url': 'https://www.khan.co.kr/article/202501161841001', 'urlToImage': 'https://img.khan.co.kr/news/2025/01/16/news-p.v1.20250116.3057712561d242d0b24d4db82ad4a854_P1.jpeg', 'publishedAt': '2025-01-16T09:41:00Z', 'content': '16 3.0% . · 1450 . .\r\n . , 12·3 · . 1400 . . 1470 (1.9%) 2.05% . .\r\n . . , . 16 2023 . 2003 21 . , .\r\n 1.8% . · , . . 1997 , 2008 . · . .\r\n16 .'}, {'source': {'id': None, 'name': 'Khan.co.kr'}, 'author': '김경민 기자 kimkim@kyunghyang.com', 'title': '미국발 ‘물가 훈풍’에 코스피 2520선 회복…환율도 1450원대', 'description': '미 12월 근원 CPI 3.2% 상승\n한은 향후 금리 인하 가능성\n환율 하락 ‘제약 요인’ 작용\n\n미국의 물가 상승 우려가 일부 해소되고 미국의 기준금리 인하 기대가 되살아나면서 16일 코스피 지수가 1% 넘게 올랐다. 원·달러 환율 역시 하락했지만, 이날 한국은행의 기준금리 동결에도 불구하고 추후 금리 인하 가능성이 더 부각되면서 환율 인하 효과는···', 'url': 'https://www.khan.co.kr/article/202501162107035', 'urlToImage': 'htt ...
# Sentiment score for 금리: -51오늘의 뉴스를 분석한 결과, 금리에 대한 감정 점수는 -51입니다. 이는 대체로 부정적인 반응을 나타냅니다. 이 정보를 바탕으로 투자 결정을 내리는 것을 고려해 보세요.
#
# > Finished chain.
# 오늘의 뉴스를 분석한 결과, 금리에 대한 감정 점수는 -51입니다. 이는 대체로 부정적인 반응을 나타냅니다. 이 정보를 바탕으로 투자 결정을 내리는 것을 고려해 보세요.
