# %%
# !pip install -q streamlit==1.41.1
# !npm install localtunnel
# Out:
# added 22 packages, and audited 23 packages in 1s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.

# %%
# %%writefile app.py

import streamlit as st


st.write('Streamlit 실습 페이지')
# Out:
# Overwriting app.py

# %%
import urllib
print("Password/Enpoint IP :",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP : : 34.143.251.71

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# your url is: https://wet-phones-brake.loca.lt
