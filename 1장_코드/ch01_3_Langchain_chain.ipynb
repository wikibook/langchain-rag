# %% [markdown]
# # Langchain Basic

# %% [markdown]
# ### module install

# %%
! pip install langchain_openai==0.2.6
! pip install langchain_community==0.3.5
# Out:
# Collecting langchain_openai==0.2.6
#   Downloading langchain_openai-0.2.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain_openai==0.2.6) (0.3.29)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai==0.2.6) (1.59.4)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain_openai==0.2.6) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (2.10.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai==0.2.6) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain_openai==0.2.6) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai==0.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.15->langchain_openai==0.2.6) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai==0.2.6) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai==0.2.6) (2.3.0)
# Downloading langchain_openai-0.2.6-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: langchain_openai
#   Attempting uninstall: langchain_openai
#     Found existing installation: langchain-openai 0.3.0
#     Uninstalling langchain-openai-0.3.0:
#       Successfully uninstalled langchain-openai-0.3.0
# Successfully installed langchain_openai-0.2.6
# Requirement already satisfied: langchain_community==0.3.5 in /usr/local/lib/python3.10/dist-packages (0.3.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (3.11.11)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (0.3.29)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community==0.3.5) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.3.5) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.5) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.5) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain_community==0.3.5) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain_community==0.3.5) (2.10.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community==0.3.5) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community==0.3.5) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community==0.3.5) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community==0.3.5) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.3.5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.3.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.3.5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community==0.3.5) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<2.0.36,>=1.4->langchain_community==0.3.5) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_community==0.3.5) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community==0.3.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community==0.3.5) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.3.5) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community==0.3.5) (1.2.2)

# %%
import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key: ··········

# %% [markdown]
# ## 1.5.1 체인(Chain)

# %% [markdown]
# ### 기본 체인 연결

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")
llm.invoke("피타고라스 정리의 공식은 무엇인가요?")
# Out:
# AIMessage(content='피타고라스 정리는 직각삼각형에서 성립하는 관계로, 다음과 같은 공식을 가지고 있습니다:\n\n\\[ a^2 + b^2 = c^2 \\]\n\n여기서:\n- \\( a \\)와 \\( b \\)는 직각삼각형의 두 직각 변의 길이,\n- \\( c \\)는 빗변의 길이입니다.\n\n즉, 직각삼각형에서 두 직각 변의 길이를 제곱하여 더한 값이 빗변의 길이를 제곱한 값과 같다는 것을 의미합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 127, 'prompt_tokens': 21, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'stop', 'logprobs': None}, id='run-62cb7527-be58-482d-91ac-40dd9ac27cb4-0', usage_metadata={'input_tokens': 21, 'output_tokens': 127, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 프롬프트 + 모델 + output parser
prompt = ChatPromptTemplate.from_template("초등학생이 이해할 수 있는 방식으로 답을 설명하세요.: <질문>: {query}")

print(prompt)
# Out:
# input_variables=['query'] input_types={} partial_variables={} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='Explain the answer in a way that an elementary school student can understand: <Question>: {query}'), additional_kwargs={})]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

chain = prompt | llm

chain.invoke({"query": "피타고라스 정리의 공식은 무엇인가요?"})
# Out:
# AIMessage(content="피타고라스 정리는 삼각형에 대한 특별한 규칙이에요. 이 규칙은 직각삼각형, 즉 한 각이 90도인 삼각형에만 적용돼요.\n\n이 정리의 공식은 이렇게 써요: **a² + b² = c²**.\n\n여기서:\n- **a**와 **b**는 직각삼각형의 두 짧은 변의 길이예요.\n- **c**는 가장 긴 변, 즉 직각삼각형의 대각선 변의 길이예요. 이 변을 '빗변'이라고도 해요.\n\n이 공식은 우리가 직각삼각형의 변의 길이를 알 때, 다른 변의 길이를 계산할 수 있도록 도와줘요. 예를 들어, 만약 한 변의 길이가 3이고 다른 변의 길이가 4라면, 빗변의 길이는 이렇게 계산할 수 있어요:\n\n3² + 4² = c²\n9 + 16 = c²\n25 = c²\n\n그럼 c의 길이는 √25, 즉 5가 돼요.\n\n그래서 피타고라스 정리는 삼각형의 변의 길이를 알 때, 나머지 변의 길이를 찾는 데 아주 유용해요!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 282, 'prompt_tokens': 38, 'total_tokens': 320, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'stop', 'logprobs': None}, id='run-0598111a-5aba-4292-b2fc-003bae742883-0', usage_metadata={'input_tokens': 38, 'output_tokens': 282, 'total_tokens': 320, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# prompt + model + output parser
prompt = ChatPromptTemplate.from_template("초등학생이 이해할 수 있는 방식으로 답을 설명하세요.: <질문>: {query}")
llm = ChatOpenAI(model="gpt-4o-mini")

# chain에 이어서 output_parser 추가
output_parser = StrOutputParser()

# LCEL chaining
chain = prompt | llm | output_parser

# chain 호출
chain.invoke({"query": "피타고라스 정리의 공식은 무엇인가요?"})
# Out:
# '피타고라스 정리는 삼각형에 관한 아주 중요한 규칙이에요. 특히 직각삼각형, 즉 한 각이 90도인 삼각형에서 적용돼요.\n\n공식은 이렇게 쓸 수 있어요:\n\n**a² + b² = c²**\n\n여기서:\n- **a**와 **b**는 직각삼각형의 두 짧은 변의 길이예요.\n- **c**는 가장 긴 변인 빗변의 길이예요.\n\n이 공식은 "짧은 변의 길이를 제곱하고 더한 값이, 긴 변의 길이를 제곱한 값과 같다"는 뜻이에요.\n\n예를 들어, 한 변의 길이가 3cm, 다른 변의 길이가 4cm인 직각삼각형이 있다고 해볼게요. 그러면:\n\n- a = 3\n- b = 4\n- c는 우리가 알아내려고 하는 길이예요.\n\n이제 공식을 사용해 볼까요?\n\n1. a² = 3² = 9\n2. b² = 4² = 16\n3. a² + b² = 9 + 16 = 25\n\n이제 c² = 25이니까 c의 길이를 찾으려면 제곱근을 계산해야 해요.\n\n4. c = √25 = 5\n\n그래서 이 삼각형의 빗변의 길이는 5cm가 돼요! 이렇게 피타고라스 정리를 사용해서 직각삼각형의 변의 길이를 알 수 있어요.'

# %% [markdown]
# ### 멀티 체인 연결

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableParallel, RunnableMap
from operator import itemgetter

# 논쟁거리 생성
basictopic = (
    ChatPromptTemplate.from_template("{topic} 에 대한 논쟁을 한국어로 생성합니다.")
    | ChatOpenAI()
    | StrOutputParser()
    | {"base": RunnablePassthrough()}
)

# 긍정 의견
positive = (
    ChatPromptTemplate.from_template(
        "{base} 의 장점 또는 긍정적인 측면을 나열하세요."
    )
    | ChatOpenAI()
    | StrOutputParser()
)

# 부정 의견
negative = (
    ChatPromptTemplate.from_template(
        "{base} 의 단점 또는 부정적인 측면을 나열하세요."
    )
    | ChatOpenAI()
    | StrOutputParser()
)

# 최종 답변
final = (
    ChatPromptTemplate.from_messages(
        [
            ("ai", "{original_response}"),
            ("human", "긍정:\n{results_1}\n\n부정:\n{results_2}"),
            ("system", "비평에 대한 최종 답변 생성"),
        ]
    )
    | ChatOpenAI()
    | StrOutputParser()
)

# RunnableParallel을 사용하여 긍정,부정 의견을 병렬로 처리
chain = (
    basictopic
    | RunnableParallel(
        results_1 = positive,
        results_2 = negative,
        original_response = itemgetter("base"),
    )
    | RunnableMap(
        {
            "positive_result": itemgetter("results_1"),
            "negative_result": itemgetter("results_2"),
            "final_answer": itemgetter("original_response"),
        }
    )
)

# chain 실행
result = chain.invoke({"topic": "social media"})

positive_result = result['positive_result']
negative_result = result['negative_result']
final_answer = result['final_answer']

print("소셜미디어에 대한 긍정 의견:\n", positive_result)
print("\n소셜미디어에 대한 부정 의견:\n", negative_result)
print("\n최종 의견",final_answer)
# Out:
# 소셜미디어에 대한 긍정 의견:
#  1. 개인정보 침해: social media를 통해 개인 정보가 공개되어 사생활이 침해될 수 있다.
# 2. 사회적 불평등: 일부 사람들은 social media를 이용하기 어려워 사회적으로 소외될 수 있으며, 정보 격차가 발생할 수 있다.
# 3. 중독성: social media의 사용이 과도하게 되면 인간관계나 현실 세계와의 소통이 저해될 수 있으며, 심리적인 문제를 초래할 수 있다.
# 4. 가짜 뉴스와 편향성: social media를 통해 빠르게 퍼지는 가짜 뉴스나 편향된 정보로 인해 사람들이 오도될 수 있고, 혼란을 야기할 수 있다.
# 5. 사이버 괴롭힘: social media를 통해 익명으로 다른 사람을 괴롭히거나 혐오 발언을 하는 경우가 늘어나고 있는데, 이는 심각한 사회 문제로 발전할 수 있다.
#
# 소셜미디어에 대한 부정 의견:
#  1. 사생활 침해: Social media를 통해 개인 정보가 쉽게 유출되어 사생활이 침해될 수 있다.
# 2. 정보 과부하: Social media를 통해 수많은 정보가 공유되어 사용자가 정보를 처리하는 능력이 약화될 수 있다.
# 3. 가짜 뉴스: Social media를 통해 가짜 뉴스가 빠르게 확산되어 사실과 다른 정보를 받아들일 수 있다.
# 4. 사회적 불평등: Social media를 통해 특정 그룹이나 개인이 더 많은 주목을 받아 사회적 불평등이 심화될 수 있다.
# 5. 사회적 분열: Social media를 통해 이기적인 의견이 강조되어 사회가 갈등과 분열을 야기할 수 있다.
# 6. 건강 문제: Social media를 통해 우울감, 불안 등의 정신건강 문제가 증가할 수 있다.
#
# 최종 의견 "Social media는 우리 사회에 긍정적인 영향을 끼치는 도구인가?"
#
# 한편으로는 social media가 소통과 정보 교환을 쉽게 만들어주어 사회적 연결성을 증가시키고 다양한 의견을 들을 수 있게 해준다는 주장도 있지만, 다른 한편으로는 사생활 침해, 정보 과부하, 가짜 뉴스 등의 부정적인 영향을 끼친다는 우려가 있다.
#
# 또한, social media를 통해 확산되는 미디어의 편향성과 선정성 문제도 논란이 되고 있다.
#
# 이러한 논쟁들을 바탕으로 social media가 우리 사회에 미치는 영향에 대해 토론해보자.
